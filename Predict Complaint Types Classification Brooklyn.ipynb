# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# The goal of this exercise is to do Model Development and Validation to find the answer to the Question 4 of the problem statement:
#
# Can a predictive model be built for future prediction of the possibility of complaints of the specific type that you identified in response to Question 1?

# %% [markdown]
# Using the best model, you need to predict the number of future complaints (of the Complaint Type that you decided to focus on in Question 1).

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor
from xgboost import to_graphviz, plot_importance

# %matplotlib inline
sns.set_style('dark')
sns.set(font_scale=1.5)

from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, mean_absolute_error, mean_squared_error,r2_score
from sklearn.metrics import plot_confusion_matrix, plot_precision_recall_curve, plot_roc_curve, accuracy_score
from sklearn.metrics import auc, f1_score, precision_score, recall_score, roc_auc_score

import feature_engine.missing_data_imputers as mdi
from feature_engine.outlier_removers import Winsorizer
from feature_engine import outlier_removers as outr

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

import warnings
warnings.filterwarnings('ignore')

import pickle
from pickle import dump, load

pd.options.display.max_columns= None
#pd.options.display.max_rows = None

# %% [markdown]
# ### Data Exploration

# %%
df = pd.read_csv("brooklynclasstrain.csv", nrows=40000)

# %%
df
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0        2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# 1        7983.0     108.00      3.84      2.0       6.0   5603.0     100.0
# 2        7983.0      48.00      1.06      2.0       2.0   2142.0     100.0
# 3        2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# 4        2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# ...         ...        ...       ...      ...       ...      ...       ...
# 39995    7983.0     108.00      1.74      2.0       4.8   5603.0     100.0
# 39996    3500.0      50.00      0.41      2.0       4.8   5603.0     100.0
# 39997    7983.0      89.58      2.21      2.0       4.8   5603.0     100.0
# 39998    7983.0      89.58      2.22      2.0       4.8   5603.0     100.0
# 39999    7983.0      79.58      2.23      2.0       4.8   5603.0     100.0
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea    Age  \
# 0           1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 1           1.0        6.0      1802.0   2060.0      5.40      1375.0   74.0
# 2           1.0        6.0      1802.0   6189.0      1.35      1375.0   80.0
# 3           1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 4           1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# ...         ...        ...         ...      ...       ...         ...    ...
# 39995       1.0        1.0      1802.0   2060.0      2.43      1375.0   85.0
# 39996       1.0        2.0      1802.0   2060.0      2.43      1375.0  105.0
# 39997       1.0        4.0      1802.0   6189.0      2.43      1375.0   95.0
# 39998       1.0        4.0      1802.0   6189.0      2.43      1375.0   77.0
# 39999       1.0        4.0      1802.0   6189.0      2.43      1375.0   94.0
#
#        Period  ComplaintType
# 0        95.0              4
# 1       100.0              1
# 2        95.0              0
# 3        95.0              2
# 4        95.0              3
# ...       ...            ...
# 39995   100.0              0
# 39996   120.0              1
# 39997   108.0              0
# 39998   109.0              0
# 39999   109.0              1
#
# [40000 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BldgArea       40000 non-null  float64
#  1   BldgDepth      40000 non-null  float64
#  2   BuiltFAR       40000 non-null  float64
#  3   CommFAR        40000 non-null  float64
#  4   FacilFAR       40000 non-null  float64
#  5   LotArea        40000 non-null  float64
#  6   LotDepth       40000 non-null  float64
#  7   NumBldgs       40000 non-null  float64
#  8   NumFloors      40000 non-null  float64
#  9   OfficeArea     40000 non-null  float64
#  10  ResArea        40000 non-null  float64
#  11  ResidFAR       40000 non-null  float64
#  12  RetailArea     40000 non-null  float64
#  13  Age            40000 non-null  float64
#  14  Period         40000 non-null  float64
#  15  ComplaintType  40000 non-null  int64
# dtypes: float64(15), int64(1)
# memory usage: 4.9 MB

# %%
df.describe(include='all')
# Out:
#           BldgArea     BldgDepth      BuiltFAR      CommFAR      FacilFAR  \
# count  40000.00000  40000.000000  40000.000000  40000.00000  40000.000000
# mean    3722.69825     54.352382      1.678697      1.96765      3.037135
# std     2006.49006     18.829125      0.771488      0.17693      1.292996
# min       40.00000      1.000000      0.010000      1.00000      1.000000
# 25%     2376.00000     43.000000      1.060000      2.00000      2.000000
# 50%     3040.00000     48.000000      1.500000      2.00000      2.000000
# 75%     4504.00000     60.000000      2.080000      2.00000      4.800000
# max     7983.00000    108.000000      3.840000      2.00000      6.000000
#
#             LotArea      LotDepth  NumBldgs     NumFloors    OfficeArea  \
# count  40000.000000  40000.000000   40000.0  40000.000000  40000.000000
# mean    2425.193075     93.517558       1.0      2.768045   1787.580975
# std     1195.334460     13.415071       0.0      0.969664    117.719234
# min        2.000000      1.000000       1.0      1.000000     48.000000
# 25%     1767.000000     93.095000       1.0      2.000000   1802.000000
# 50%     2003.000000    100.000000       1.0      3.000000   1802.000000
# 75%     2504.000000    100.000000       1.0      3.000000   1802.000000
# max     5603.000000    100.000000       1.0      6.000000   1802.000000
#
#             ResArea      ResidFAR    RetailArea           Age        Period  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean    2836.579800      2.285844   1349.203700     84.684275    101.295500
# std     1491.340278      0.916295    108.742884     26.623549     25.467326
# min      200.000000      0.500000     70.000000    -45.000000      2.000000
# 25%     1938.000000      2.000000   1375.000000     76.000000     95.000000
# 50%     2208.000000      2.000000   1375.000000     90.000000    110.000000
# 75%     3300.000000      2.430000   1375.000000    104.000000    119.000000
# max     6189.000000      7.020000   1375.000000    165.000000    174.000000
#
#        ComplaintType
# count   40000.000000
# mean        1.306350
# std         1.281148
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         4.000000

# %%
df.shape
# Out:
# (40000, 16)

# %%
df.columns
# Out:
# Index(['BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'LotArea',
#        'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea',
#        'ResidFAR', 'RetailArea', 'Age', 'Period', 'ComplaintType'],
#       dtype='object')

# %%
df['ComplaintType'].value_counts()
# Out:
# 1    13723
# 0    12993
# 2     4941
# 3     4723
# 4     3620
# Name: ComplaintType, dtype: int64

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# ### Univariate Data Exploration

# %%
fig = plt.figure(figsize=(20,40))

plt.subplot(7,2,1)
sns.countplot(df.ComplaintType)
plt.subplot(7,2,2)
sns.distplot(df.BldgArea)
plt.subplot(7,2,3)
sns.distplot(df.BldgDepth)
plt.subplot(7,2,4)
sns.distplot(df.BuiltFAR)
plt.subplot(7,2,5)
sns.countplot(df.NumBldgs)
plt.subplot(7,2,6)
sns.countplot(df.NumFloors)
# plt.subplot(7,2,7)
# sns.countplot(df.Age)
# plt.subplot(7,2,8)
# sns.countplot(df.Period)
# plt.subplot(7,2,9)
# sns.countplot()
# plt.subplot(7,2,10)
# sns.countplot()
# plt.subplot(7,2,11)
# sns.countplot()
# plt.subplot(7,2,12)
# sns.countplot()
# plt.subplot(7,2,13)
# sns.countplot()
# plt.subplot(7,2,14)
# sns.countplot()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate Data Exploration

# %%
df.corr()
# Out:
#                BldgArea  BldgDepth  BuiltFAR   CommFAR  FacilFAR   LotArea  \
# BldgArea       1.000000   0.700255  0.706540  0.000077  0.224778  0.652663
# BldgDepth      0.700255   1.000000  0.398131 -0.060306  0.223735  0.600595
# BuiltFAR       0.706540   0.398131  1.000000  0.099798  0.216169  0.128446
# CommFAR        0.000077  -0.060306  0.099798  1.000000  0.092852 -0.095802
# FacilFAR       0.224778   0.223735  0.216169  0.092852  1.000000  0.168979
# LotArea        0.652663   0.600595  0.128446 -0.095802  0.168979  1.000000
# LotDepth       0.108998   0.191426 -0.196657  0.030455 -0.096930  0.309584
# NumBldgs            NaN        NaN       NaN       NaN       NaN       NaN
# NumFloors      0.609319   0.228143  0.772645  0.120090  0.161213  0.186737
# OfficeArea    -0.065936  -0.095294 -0.017309  0.025992 -0.055558 -0.077148
# ResArea        0.766617   0.455671  0.682315  0.075144  0.151766  0.365224
# ResidFAR       0.253027   0.147269  0.382583  0.181657  0.550923  0.066728
# RetailArea     0.055588   0.064214 -0.095557  0.008240 -0.084325  0.137978
# Age           -0.307316  -0.325826 -0.164040  0.095005 -0.097536 -0.313804
# Period        -0.262436  -0.298311 -0.128934  0.097914 -0.081884 -0.289630
# ComplaintType  0.004077   0.005585  0.001577  0.005781  0.001436  0.003889
#
#                LotDepth  NumBldgs  NumFloors  OfficeArea   ResArea  ResidFAR  \
# BldgArea       0.108998       NaN   0.609319   -0.065936  0.766617  0.253027
# BldgDepth      0.191426       NaN   0.228143   -0.095294  0.455671  0.147269
# BuiltFAR      -0.196657       NaN   0.772645   -0.017309  0.682315  0.382583
# CommFAR        0.030455       NaN   0.120090    0.025992  0.075144  0.181657
# FacilFAR      -0.096930       NaN   0.161213   -0.055558  0.151766  0.550923
# LotArea        0.309584       NaN   0.186737   -0.077148  0.365224  0.066728
# LotDepth       1.000000       NaN  -0.019010    0.029338  0.096429 -0.141226
# NumBldgs            NaN       NaN        NaN         NaN       NaN       NaN
# NumFloors     -0.019010       NaN   1.000000    0.025726  0.716832  0.336743
# OfficeArea     0.029338       NaN   0.025726    1.000000  0.015366 -0.015327
# ResArea        0.096429       NaN   0.716832    0.015366  1.000000  0.212310
# ResidFAR      -0.141226       NaN   0.336743   -0.015327  0.212310  1.000000
# RetailArea     0.242531       NaN  -0.069464    0.020960  0.095269 -0.137276
# Age            0.044864       NaN  -0.154751    0.095713 -0.218228 -0.039587
# Period         0.043639       NaN  -0.121749    0.087976 -0.176985 -0.021761
# ComplaintType  0.005763       NaN   0.004087   -0.003897  0.003491  0.001783
#
#                RetailArea       Age    Period  ComplaintType
# BldgArea         0.055588 -0.307316 -0.262436       0.004077
# BldgDepth        0.064214 -0.325826 -0.298311       0.005585
# BuiltFAR        -0.095557 -0.164040 -0.128934       0.001577
# CommFAR          0.008240  0.095005  0.097914       0.005781
# FacilFAR        -0.084325 -0.097536 -0.081884       0.001436
# LotArea          0.137978 -0.313804 -0.289630       0.003889
# LotDepth         0.242531  0.044864  0.043639       0.005763
# NumBldgs              NaN       NaN       NaN            NaN
# NumFloors       -0.069464 -0.154751 -0.121749       0.004087
# OfficeArea       0.020960  0.095713  0.087976      -0.003897
# ResArea          0.095269 -0.218228 -0.176985       0.003491
# ResidFAR        -0.137276 -0.039587 -0.021761       0.001783
# RetailArea       1.000000  0.027709  0.023377       0.004905
# Age              0.027709  1.000000  0.957572       0.005296
# Period           0.023377  0.957572  1.000000       0.005754
# ComplaintType    0.004905  0.005296  0.005754       1.000000

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.corr(),cmap="coolwarm",annot=True,fmt='.2f',linewidths=2)
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ### Treat Duplicate Values

# %%
df.duplicated(keep='first').sum()
# Out:
# 5356

# %%
df[df.duplicated(keep=False)]
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0        2430.0       48.0      1.06      2.0       2.0   5603.0     100.0
# 3        2430.0       48.0      1.06      2.0       2.0   5603.0     100.0
# 4        2430.0       48.0      1.06      2.0       2.0   5603.0     100.0
# 5        2430.0       48.0      1.06      2.0       2.0   2142.0     100.0
# 6        2430.0       48.0      1.06      2.0       2.0   2142.0     100.0
# ...         ...        ...       ...      ...       ...      ...       ...
# 39959    2208.0       55.0      1.10      2.0       4.8   2000.0     100.0
# 39960    2208.0       55.0      1.10      2.0       4.8   2000.0     100.0
# 39961    2208.0       55.0      1.10      2.0       4.8   2000.0     100.0
# 39990    1332.0       37.0      0.82      2.0       4.8   1620.0      90.0
# 39991    1332.0       37.0      0.82      2.0       4.8   1620.0      90.0
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0           1.0        2.0      1802.0   2060.0      1.35      1375.0  80.0
# 3           1.0        2.0      1802.0   2060.0      1.35      1375.0  80.0
# 4           1.0        2.0      1802.0   2060.0      1.35      1375.0  80.0
# 5           1.0        2.0      1802.0   2060.0      1.35      1375.0  80.0
# 6           1.0        2.0      1802.0   2060.0      1.35      1375.0  80.0
# ...         ...        ...         ...      ...       ...         ...   ...
# 39959       1.0        2.0      1802.0   2208.0      2.43      1375.0  95.0
# 39960       1.0        2.0      1802.0   2208.0      2.43      1375.0  95.0
# 39961       1.0        2.0      1802.0   2208.0      2.43      1375.0  95.0
# 39990       1.0        2.0      1802.0   2060.0      2.43      1375.0  85.0
# 39991       1.0        2.0      1802.0   2060.0      2.43      1375.0  85.0
#
#        Period  ComplaintType
# 0        95.0              4
# 3        95.0              2
# 4        95.0              3
# 5        95.0              0
# 6        95.0              0
# ...       ...            ...
# 39959   110.0              0
# 39960   110.0              0
# 39961   110.0              1
# 39990   100.0              1
# 39991   100.0              1
#
# [8368 rows x 16 columns]

# %%
df.drop_duplicates(keep='first',ignore_index=True, inplace=True)

# %%
df
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0        2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# 1        7983.0     108.00      3.84      2.0       6.0   5603.0     100.0
# 2        7983.0      48.00      1.06      2.0       2.0   2142.0     100.0
# 3        2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# 4        2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# ...         ...        ...       ...      ...       ...      ...       ...
# 34639    7983.0     108.00      1.74      2.0       4.8   5603.0     100.0
# 34640    3500.0      50.00      0.41      2.0       4.8   5603.0     100.0
# 34641    7983.0      89.58      2.21      2.0       4.8   5603.0     100.0
# 34642    7983.0      89.58      2.22      2.0       4.8   5603.0     100.0
# 34643    7983.0      79.58      2.23      2.0       4.8   5603.0     100.0
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea    Age  \
# 0           1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 1           1.0        6.0      1802.0   2060.0      5.40      1375.0   74.0
# 2           1.0        6.0      1802.0   6189.0      1.35      1375.0   80.0
# 3           1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 4           1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# ...         ...        ...         ...      ...       ...         ...    ...
# 34639       1.0        1.0      1802.0   2060.0      2.43      1375.0   85.0
# 34640       1.0        2.0      1802.0   2060.0      2.43      1375.0  105.0
# 34641       1.0        4.0      1802.0   6189.0      2.43      1375.0   95.0
# 34642       1.0        4.0      1802.0   6189.0      2.43      1375.0   77.0
# 34643       1.0        4.0      1802.0   6189.0      2.43      1375.0   94.0
#
#        Period  ComplaintType
# 0        95.0              4
# 1       100.0              1
# 2        95.0              0
# 3        95.0              2
# 4        95.0              3
# ...       ...            ...
# 34639   100.0              0
# 34640   120.0              1
# 34641   108.0              0
# 34642   109.0              0
# 34643   109.0              1
#
# [34644 rows x 16 columns]

# %% [markdown]
# ### HEAT/HOT WATER = 0; OTHERS = 1, PAINT/PLASTER = 2, PLUMBING = 3, UNSANITARY CONDITION = 4

# %% [markdown]
# ### Train Test Split

# %%
X = df.iloc[:,0:15]
y = df.iloc[:,15]

# %% [markdown]
# ### Treat Imbalance Data

# %%
y.value_counts()
# Out:
# 1    11433
# 0    10987
# 2     4523
# 3     4305
# 4     3396
# Name: ComplaintType, dtype: int64

# %%
ros = RandomOverSampler(sampling_strategy='all',random_state=0)

# %%
new_X, new_y = ros.fit_resample(X, y)

# %%
new_y.value_counts()
# Out:
# 4    11433
# 3    11433
# 2    11433
# 1    11433
# 0    11433
# Name: ComplaintType, dtype: int64

# %%
new_X
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0        2430.0       48.0      1.06      2.0       2.0   5603.0     100.0
# 1        7983.0      108.0      3.84      2.0       6.0   5603.0     100.0
# 2        7983.0       48.0      1.06      2.0       2.0   2142.0     100.0
# 3        2430.0       48.0      1.06      2.0       2.0   5603.0     100.0
# 4        2430.0       48.0      1.06      2.0       2.0   5603.0     100.0
# ...         ...        ...       ...      ...       ...      ...       ...
# 57160    7983.0      100.0      1.00      2.0       4.8   5603.0     100.0
# 57161    2112.0       42.0      0.94      2.0       2.0   2250.0     100.0
# 57162    1900.0       96.0      0.95      2.0       2.0   2000.0     100.0
# 57163    4536.0       66.0      1.62      2.0       3.0   2800.0     100.0
# 57164    2520.0       60.0      0.96      2.0       2.0   2616.0     100.0
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea    Age  \
# 0           1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 1           1.0        6.0      1802.0   2060.0      5.40      1375.0   74.0
# 2           1.0        6.0      1802.0   6189.0      1.35      1375.0   80.0
# 3           1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 4           1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# ...         ...        ...         ...      ...       ...         ...    ...
# 57160       1.0        1.0      1802.0   2060.0      3.44      1375.0   80.0
# 57161       1.0        3.0      1802.0   2112.0      2.00      1375.0  106.0
# 57162       1.0        1.0      1802.0   2060.0      2.00      1375.0   74.0
# 57163       1.0        2.0      1802.0   2060.0      3.00      1375.0   90.0
# 57164       1.0        2.0      1802.0   2520.0      2.00      1375.0   85.0
#
#        Period
# 0        95.0
# 1       100.0
# 2        95.0
# 3        95.0
# 4        95.0
# ...       ...
# 57160    95.0
# 57161   121.0
# 57162    89.0
# 57163   100.0
# 57164   100.0
#
# [57165 rows x 15 columns]

# %%
new_X.values, new_y.values
# Out:
# (array([[2.430e+03, 4.800e+01, 1.060e+00, ..., 1.375e+03, 8.000e+01,
#          9.500e+01],
#         [7.983e+03, 1.080e+02, 3.840e+00, ..., 1.375e+03, 7.400e+01,
#          1.000e+02],
#         [7.983e+03, 4.800e+01, 1.060e+00, ..., 1.375e+03, 8.000e+01,
#          9.500e+01],
#         ...,
#         [1.900e+03, 9.600e+01, 9.500e-01, ..., 1.375e+03, 7.400e+01,
#          8.900e+01],
#         [4.536e+03, 6.600e+01, 1.620e+00, ..., 1.375e+03, 9.000e+01,
#          1.000e+02],
#         [2.520e+03, 6.000e+01, 9.600e-01, ..., 1.375e+03, 8.500e+01,
#          1.000e+02]]),
#  array([4, 1, 0, ..., 4, 4, 4], dtype=int64))

# %%
X_train, X_test, y_train, y_test = train_test_split(new_X.values, new_y.values, test_size=0.2, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((45732, 15), (11433, 15), (45732,), (11433,))

# %% [markdown]
# ### Feature Scaling

# %%
X_train
# Out:
# array([[7.308e+03, 8.750e+01, 1.930e+00, ..., 1.375e+03, 9.700e+01,
#         1.120e+02],
#        [3.560e+03, 5.000e+01, 1.480e+00, ..., 1.375e+03, 1.060e+02,
#         1.210e+02],
#        [3.000e+03, 5.000e+01, 1.110e+00, ..., 1.375e+03, 1.060e+02,
#         1.210e+02],
#        ...,
#        [1.944e+03, 3.500e+01, 1.610e+00, ..., 1.375e+03, 1.060e+02,
#         1.210e+02],
#        [2.934e+03, 7.300e+01, 1.150e+00, ..., 1.375e+03, 7.000e+01,
#         8.500e+01],
#        [6.002e+03, 4.200e+01, 2.590e+00, ..., 1.375e+03, 1.550e+02,
#         1.700e+02]])

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 1.68472073,  1.66765633,  0.26164497, ...,  0.24380853,
#          0.47780598,  0.43058646],
#        [-0.13879606, -0.25452675, -0.30505943, ...,  0.24380853,
#          0.8060144 ,  0.77419342],
#        [-0.41125322, -0.25452675, -0.77101638, ...,  0.24380853,
#          0.8060144 ,  0.77419342],
#        ...,
#        [-0.92502956, -1.02339999, -0.14134482, ...,  0.24380853,
#          0.8060144 ,  0.77419342],
#        [-0.44336424,  0.92441221, -0.72064266, ...,  0.24380853,
#         -0.5068193 , -0.6002344 ],
#        [ 1.04931173, -0.66459248,  1.09281143, ...,  0.24380853,
#          2.59292695,  2.64494239]])

# %%
X_test_scaled
# Out:
# array([[-0.25556342, -0.51081783, -0.07837767, ...,  0.24380853,
#          0.7330792 ,  0.69783632],
#        [-0.89778385,  2.30838403, -0.90954413, ...,  0.24380853,
#         -2.00199102, -0.4475202 ],
#        [-0.48423281, -0.83528234, -0.56952148, ...,  0.24380853,
#          0.8060144 ,  0.77419342],
#        ...,
#        [-0.45358138,  0.36057183, -0.56952148, ...,  0.24380853,
#          0.04019474, -0.02755614],
#        [-0.60586547, -0.51081783, -0.53174119, ...,  0.24380853,
#         -1.12676855, -1.36380541],
#        [-0.68857568, -0.35704319, -0.83398354, ...,  0.24380853,
#         -0.14214327, -0.2184489 ]])

# %%
y_train
# Out:
# array([2, 1, 3, ..., 3, 3, 2], dtype=int64)

# %%
y_test
# Out:
# array([3, 4, 4, ..., 0, 3, 2], dtype=int64)

# %% [markdown]
# ### Model Training

# %% [markdown]
# ### Using XGBoost (Scikit-Learn)

# %%
xgbmodel = XGBClassifier(random_state=0, n_estimators=300, objective='multi:softmax')

# %%
xgbmodel.fit(X_train_scaled,y_train,eval_set=[(X_test_scaled,y_test)],eval_metric='merror',early_stopping_rounds=10)
# Out:
# [0]	validation_0-merror:0.793318
# Will train until validation_0-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.792705
# [2]	validation_0-merror:0.791131
# [3]	validation_0-merror:0.792181
# [4]	validation_0-merror:0.791043
# [5]	validation_0-merror:0.792968
# [6]	validation_0-merror:0.794455
# [7]	validation_0-merror:0.790081
# [8]	validation_0-merror:0.789469
# [9]	validation_0-merror:0.789644
# [10]	validation_0-merror:0.788332
# [11]	validation_0-merror:0.786845
# [12]	validation_0-merror:0.78772
# [13]	validation_0-merror:0.78772
# [14]	validation_0-merror:0.78772
# [15]	validation_0-merror:0.785183
# [16]	validation_0-merror:0.785008
# [17]	validation_0-merror:0.78597
# [18]	validation_0-merror:0.78597
# [19]	validation_0-merror:0.783871
# [20]	validation_0-merror:0.782647
# [21]	validation_0-merror:0.783696
# [22]	validation_0-merror:0.781947
# [23]	validation_0-merror:0.780897
# [24]	validation_0-merror:0.781947
# [25]	validation_0-merror:0.781072
# [26]	validation_0-merror:0.78011
# [27]	validation_0-merror:0.779673
# [28]	validation_0-merror:0.781335
# [29]	validation_0-merror:0.781422
# [30]	validation_0-merror:0.780897
# [31]	validation_0-merror:0.780548
# [32]	validation_0-merror:0.779061
# [33]	validation_0-merror:0.778536
# [34]	validation_0-merror:0.779673
# [35]	validation_0-merror:0.778186
# [36]	validation_0-merror:0.778798
# [37]	validation_0-merror:0.779236
# [38]	validation_0-merror:0.778973
# [39]	validation_0-merror:0.779061
# [40]	validation_0-merror:0.779236
# [41]	validation_0-merror:0.778536
# [42]	validation_0-merror:0.778798
# [43]	validation_0-merror:0.778886
# [44]	validation_0-merror:0.778623
# [45]	validation_0-merror:0.778361
# Stopping. Best iteration:
# [35]	validation_0-merror:0.778186
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=300, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred = xgbmodel.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([4, 2, 1, ..., 4, 2, 2], dtype=int64)

# %% [markdown]
# ### Model Evaluation

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[419, 510, 345, 208, 741],
#        [429, 481, 339, 232, 744],
#        [405, 479, 395, 232, 793],
#        [394, 539, 352, 281, 802],
#        [354, 499, 345, 155, 960]], dtype=int64)

# %%
fig , ax = plt.subplots(figsize=(10,5))
sns.heatmap(cm, annot=True,fmt='.4g',linewidths=2, cmap='viridis')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.21      0.19      0.20      2223
#            1       0.19      0.22      0.20      2225
#            2       0.22      0.17      0.19      2304
#            3       0.25      0.12      0.16      2368
#            4       0.24      0.42      0.30      2313
#
#     accuracy                           0.22     11433
#    macro avg       0.22      0.22      0.21     11433
# weighted avg       0.22      0.22      0.21     11433

# %% [markdown]
# ### Available importance_types = [‘weight’, ‘gain’, ‘cover’, ‘total_gain’, ‘total_cover’]

# %%
X.columns
# Out:
# Index(['BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'LotArea',
#        'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea',
#        'ResidFAR', 'RetailArea', 'Age', 'Period'],
#       dtype='object')

# %%
xgbmodel.get_booster().feature_names = ['BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'LotArea',
       'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea','ResidFAR', 'RetailArea', 'Age', 'Period']

# %%
fig, ax = plt.subplots(figsize=(20,10))
xgb.plot_importance(xgbmodel.get_booster(),ax=ax)
plt.show()

# %%
xgb.to_graphviz(xgbmodel,num_trees=110)

# %% [markdown]
# ### Cross-Validation

# %%
cv = cross_val_score(xgbmodel,X_train_scaled,y_train,cv=5,verbose=1,scoring='accuracy')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  2.3min finished

# %%
cv.mean()
# Out:
# 0.2662030984982726

# %% [markdown]
# ### Using XGBoost (API)

# %% [markdown]
# {'subsample': 0.7999999999999999,
#  'n_estimators': 800,
#  'min_child_weight': 2,
#  'max_depth': 4,
#  'learning rate': 0.05,
#  'gamma': 0,
#  'colsample_bytree': 0.7}

# %%
dtrain = xgb.DMatrix(data=X_train_scaled,label=y_train)
dtest = xgb.DMatrix(data=X_test_scaled,label=y_test)

# %%
params = {'n_estimators': 800,
          'learning_rate': 0.05,
          'max_depth': 4,
          'min_child_weight': 2,
          'objective': 'multi:softmax',
          'num_class': 5 ,
          'seed': 0,
          'colsample_bytree': 0.7,
          'subsample' : 0.8,
          'eval_metric':'merror'}

# %%
xgbmodel = xgb.train(params=params,dtrain=dtrain,num_boost_round=500,evals=[(dtest,"Test")],
                     early_stopping_rounds=10)
# Out:
# [0]	Test-merror:0.787895
# Will train until Test-merror hasn't improved in 10 rounds.
# [1]	Test-merror:0.79393
# [2]	Test-merror:0.783521
# [3]	Test-merror:0.785271
# [4]	Test-merror:0.785708
# [5]	Test-merror:0.779061
# [6]	Test-merror:0.778711
# [7]	Test-merror:0.779061
# [8]	Test-merror:0.779935
# [9]	Test-merror:0.779148
# [10]	Test-merror:0.776437
# [11]	Test-merror:0.777311
# [12]	Test-merror:0.775912
# [13]	Test-merror:0.776612
# [14]	Test-merror:0.775912
# [15]	Test-merror:0.773375
# [16]	Test-merror:0.774512
# [17]	Test-merror:0.775649
# [18]	Test-merror:0.775474
# [19]	Test-merror:0.776174
# [20]	Test-merror:0.773725
# [21]	Test-merror:0.773988
# [22]	Test-merror:0.775125
# [23]	Test-merror:0.773725
# [24]	Test-merror:0.772151
# [25]	Test-merror:0.772851
# [26]	Test-merror:0.772063
# [27]	Test-merror:0.771276
# [28]	Test-merror:0.771101
# [29]	Test-merror:0.770489
# [30]	Test-merror:0.772151
# [31]	Test-merror:0.769877
# [32]	Test-merror:0.768127
# [33]	Test-merror:0.768827
# [34]	Test-merror:0.766465
# [35]	Test-merror:0.767778
# [36]	Test-merror:0.764104
# [37]	Test-merror:0.763754
# [38]	Test-merror:0.761567
# [39]	Test-merror:0.762267
# [40]	Test-merror:0.76078
# [41]	Test-merror:0.759818
# [42]	Test-merror:0.761567
# [43]	Test-merror:0.761742
# [44]	Test-merror:0.761218
# [45]	Test-merror:0.759118
# [46]	Test-merror:0.759906
# [47]	Test-merror:0.759906
# [48]	Test-merror:0.759206
# [49]	Test-merror:0.758856
# [50]	Test-merror:0.758069
# [51]	Test-merror:0.759118
# [52]	Test-merror:0.758768
# [53]	Test-merror:0.759381
# [54]	Test-merror:0.756932
# [55]	Test-merror:0.757194
# [56]	Test-merror:0.757719
# [57]	Test-merror:0.758856
# [58]	Test-merror:0.757719
# [59]	Test-merror:0.756494
# [60]	Test-merror:0.756232
# [61]	Test-merror:0.755795
# [62]	Test-merror:0.754395
# [63]	Test-merror:0.753958
# [64]	Test-merror:0.75457
# [65]	Test-merror:0.755532
# [66]	Test-merror:0.756232
# [67]	Test-merror:0.75492
# [68]	Test-merror:0.754133
# [69]	Test-merror:0.754395
# [70]	Test-merror:0.753083
# [71]	Test-merror:0.753608
# [72]	Test-merror:0.75387
# [73]	Test-merror:0.753346
# [74]	Test-merror:0.75352
# [75]	Test-merror:0.752646
# [76]	Test-merror:0.752383
# [77]	Test-merror:0.751946
# [78]	Test-merror:0.750109
# [79]	Test-merror:0.750809
# [80]	Test-merror:0.749585
# [81]	Test-merror:0.748972
# [82]	Test-merror:0.749147
# [83]	Test-merror:0.748622
# [84]	Test-merror:0.74906
# [85]	Test-merror:0.748972
# [86]	Test-merror:0.74941
# [87]	Test-merror:0.749672
# [88]	Test-merror:0.750809
# [89]	Test-merror:0.750722
# [90]	Test-merror:0.750372
# [91]	Test-merror:0.749672
# [92]	Test-merror:0.74871
# [93]	Test-merror:0.749759
# Stopping. Best iteration:
# [83]	Test-merror:0.748622

# %%
y_pred = xgbmodel.predict(dtest)

# %%
y_pred
# Out:
# array([4., 2., 4., ..., 4., 2., 2.], dtype=float32)

# %% [markdown]
# ### Cross-Validation (API)

# %%
 cv = xgb.cv(params=params,
             dtrain=dtrain,
             num_boost_round=100,
             nfold=5,
             stratified=False,
             folds=None,
             metrics=('merror'),
             obj=None,
             feval=None,
             maximize=False,
             early_stopping_rounds=10,
             fpreproc=None,
             as_pandas=True,
             verbose_eval=None,
             show_stdv=True,
             seed=0,
             callbacks=None,
             shuffle=True,)

# %%
cv
# Out:
#     train-merror-mean  train-merror-std  test-merror-mean  test-merror-std
# 0            0.775617          0.001436          0.789469         0.004093
# 1            0.765777          0.004443          0.785730         0.005688
# 2            0.759086          0.003463          0.783915         0.004804
# 3            0.753510          0.002978          0.780831         0.004886
# 4            0.750301          0.004165          0.779367         0.004454
# ..                ...               ...               ...              ...
# 95           0.673117          0.004274          0.746151         0.006065
# 96           0.672456          0.004552          0.746326         0.005955
# 97           0.672248          0.004762          0.746020         0.006259
# 98           0.671608          0.004240          0.745955         0.006225
# 99           0.670750          0.004180          0.745474         0.005849
#
# [100 rows x 4 columns]

# %%
cv['test-merror-mean'].min()
# Out:
# 0.7454736000000001

# %% [markdown]
# ### Model Evaluation

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[ 398,  471,  399,  289,  666],
#        [ 441,  396,  388,  300,  700],
#        [ 337,  387,  556,  264,  760],
#        [ 356,  416,  375,  466,  755],
#        [ 295,  371,  364,  238, 1045]], dtype=int64)

# %%
fig , ax = plt.subplots(figsize=(10,5))
sns.heatmap(cm, annot=True,fmt='.4g',linewidths=2, cmap='viridis')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.22      0.18      0.20      2223
#            1       0.19      0.18      0.19      2225
#            2       0.27      0.24      0.25      2304
#            3       0.30      0.20      0.24      2368
#            4       0.27      0.45      0.33      2313
#
#     accuracy                           0.25     11433
#    macro avg       0.25      0.25      0.24     11433
# weighted avg       0.25      0.25      0.24     11433

# %% [markdown]
# ### Model Tuning

# %% [markdown]
# ### Using RandomSearchCV

# %%
df = pd.read_csv("brooklynclasstrain.csv", nrows=2000)

# %%
df.duplicated(keep='first').sum()
# Out:
# 102

# %%
df[df.duplicated(keep=False)]
# Out:
#       BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0       2430.0       48.0      1.06      2.0       2.0   5603.0    100.00
# 3       2430.0       48.0      1.06      2.0       2.0   5603.0    100.00
# 4       2430.0       48.0      1.06      2.0       2.0   5603.0    100.00
# 5       2430.0       48.0      1.06      2.0       2.0   2142.0    100.00
# 6       2430.0       48.0      1.06      2.0       2.0   2142.0    100.00
# ...        ...        ...       ...      ...       ...      ...       ...
# 1786    2430.0       48.0      1.06      2.0       2.0   5603.0    100.00
# 1813    3024.0       42.0      2.23      2.0       4.8   1358.0     75.42
# 1814    3024.0       42.0      2.23      2.0       4.8   1358.0     75.42
# 1852    2096.0       25.0      2.09      2.0       4.8   1003.0     50.17
# 1853    2096.0       25.0      2.09      2.0       4.8   1003.0     50.17
#
#       NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea    Age  \
# 0          1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 3          1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 4          1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 5          1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 6          1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# ...        ...        ...         ...      ...       ...         ...    ...
# 1786       1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 1813       1.0        3.0      1802.0   2268.0      2.43      1375.0  106.0
# 1814       1.0        3.0      1802.0   2268.0      2.43      1375.0  106.0
# 1852       1.0        3.0      1802.0   1572.0      3.44      1375.0  106.0
# 1853       1.0        3.0      1802.0   1572.0      3.44      1375.0  106.0
#
#       Period  ComplaintType
# 0       95.0              4
# 3       95.0              2
# 4       95.0              3
# 5       95.0              0
# 6       95.0              0
# ...      ...            ...
# 1786    95.0              2
# 1813   121.0              1
# 1814   121.0              1
# 1852   121.0              0
# 1853   121.0              0
#
# [171 rows x 16 columns]

# %%
df.drop_duplicates(keep='first',ignore_index=True, inplace=True)

# %%
df
# Out:
#       BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0       2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# 1       7983.0     108.00      3.84      2.0       6.0   5603.0     100.0
# 2       7983.0      48.00      1.06      2.0       2.0   2142.0     100.0
# 3       2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# 4       2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# ...        ...        ...       ...      ...       ...      ...       ...
# 1893    7368.0      40.00      2.97      2.0       4.8   2482.0     100.0
# 1894    4160.0      42.17      1.67      2.0       4.8   2491.0     100.0
# 1895    5431.0      67.00      2.13      2.0       4.8   2550.0     100.0
# 1896    5400.0      65.00      2.12      2.0       4.8   2550.0     100.0
# 1897    2250.0      80.00      0.90      2.0       4.8   2500.0     100.0
#
#       NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea    Age  \
# 0          1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 1          1.0        6.0      1802.0   2060.0      5.40      1375.0   74.0
# 2          1.0        6.0      1802.0   6189.0      1.35      1375.0   80.0
# 3          1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# 4          1.0        2.0      1802.0   2060.0      1.35      1375.0   80.0
# ...        ...        ...         ...      ...       ...         ...    ...
# 1893       1.0        4.0      1802.0   6189.0      2.43      1375.0  158.0
# 1894       1.0        3.0      1802.0   3040.0      2.43      1375.0  159.0
# 1895       1.0        3.0      1802.0   5431.0      2.43      1375.0  146.0
# 1896       1.0        3.0      1802.0   3870.0      2.43      1375.0  143.0
# 1897       1.0        1.0      1802.0   2060.0      3.44      1375.0   80.0
#
#       Period  ComplaintType
# 0       95.0              4
# 1      100.0              1
# 2       95.0              0
# 3       95.0              2
# 4       95.0              3
# ...      ...            ...
# 1893   173.0              3
# 1894   174.0              1
# 1895   174.0              1
# 1896   174.0              3
# 1897    95.0              1
#
# [1898 rows x 16 columns]

# %% [markdown]
# ### HEAT/HOT WATER = 0; OTHERS = 1, PAINT/PLASTER = 2, PLUMBING = 3, UNSANITARY CONDITION = 4

# %% [markdown]
# ### Train Test Split

# %%
X = df.iloc[:,0:15]
y = df.iloc[:,15]

# %%
y.value_counts()
# Out:
# 1    659
# 0    620
# 2    226
# 3    217
# 4    176
# Name: ComplaintType, dtype: int64

# %%
ros = RandomOverSampler(sampling_strategy='all',random_state=0)

# %%
new_X, new_y = ros.fit_resample(X, y)

# %%
new_y.value_counts()
# Out:
# 3    659
# 1    659
# 4    659
# 2    659
# 0    659
# Name: ComplaintType, dtype: int64

# %%
new_X
# Out:
#       BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0       2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# 1       7983.0     108.00      3.84      2.0       6.0   5603.0     100.0
# 2       7983.0      48.00      1.06      2.0       2.0   2142.0     100.0
# 3       2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# 4       2430.0      48.00      1.06      2.0       2.0   5603.0     100.0
# ...        ...        ...       ...      ...       ...      ...       ...
# 3290    2109.0      40.00      1.17      2.0       2.0   1802.0      92.0
# 3291    2430.0      48.00      1.06      2.0       2.0   2142.0     100.0
# 3292    7983.0      83.58      3.84      2.0       6.0   5603.0      47.5
# 3293    2430.0      48.00      1.06      2.0       6.0   2940.0      70.0
# 3294    3360.0      46.00      1.98      2.0       2.0   1700.0      85.0
#
#       NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0          1.0        2.0      1802.0   2060.0      1.35      1375.0  80.0
# 1          1.0        6.0      1802.0   2060.0      5.40      1375.0  74.0
# 2          1.0        6.0      1802.0   6189.0      1.35      1375.0  80.0
# 3          1.0        2.0      1802.0   2060.0      1.35      1375.0  80.0
# 4          1.0        2.0      1802.0   2060.0      1.35      1375.0  80.0
# ...        ...        ...         ...      ...       ...         ...   ...
# 3290       1.0        3.0      1802.0   2109.0      2.00      1375.0  90.0
# 3291       1.0        2.0      1802.0   2060.0      1.35      1375.0  80.0
# 3292       1.0        6.0      1802.0   2060.0      5.40      1375.0  77.0
# 3293       1.0        2.0      1802.0   2060.0      3.44      1375.0  80.0
# 3294       1.0        3.0      1802.0   2440.0      2.00      1375.0  46.0
#
#       Period
# 0       95.0
# 1      100.0
# 2       95.0
# 3       95.0
# 4       95.0
# ...      ...
# 3290   105.0
# 3291    95.0
# 3292   110.0
# 3293    95.0
# 3294   100.0
#
# [3295 rows x 15 columns]

# %%
new_X.values, new_y.values
# Out:
# (array([[2.430e+03, 4.800e+01, 1.060e+00, ..., 1.375e+03, 8.000e+01,
#          9.500e+01],
#         [7.983e+03, 1.080e+02, 3.840e+00, ..., 1.375e+03, 7.400e+01,
#          1.000e+02],
#         [7.983e+03, 4.800e+01, 1.060e+00, ..., 1.375e+03, 8.000e+01,
#          9.500e+01],
#         ...,
#         [7.983e+03, 8.358e+01, 3.840e+00, ..., 1.375e+03, 7.700e+01,
#          1.100e+02],
#         [2.430e+03, 4.800e+01, 1.060e+00, ..., 1.375e+03, 8.000e+01,
#          9.500e+01],
#         [3.360e+03, 4.600e+01, 1.980e+00, ..., 1.375e+03, 4.600e+01,
#          1.000e+02]]),
#  array([4, 1, 0, ..., 4, 4, 4], dtype=int64))

# %%
X_train, X_test, y_train, y_test = train_test_split(new_X.values, new_y.values, test_size=0.2, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2636, 15), (659, 15), (2636,), (659,))

# %%
X_train
# Out:
# array([[3.600e+03, 4.500e+01, 1.800e+00, ..., 1.375e+03, 9.000e+01,
#         1.050e+02],
#        [1.500e+03, 2.500e+01, 3.000e+00, ..., 1.375e+03, 1.060e+02,
#         1.210e+02],
#        [2.664e+03, 4.000e+01, 1.750e+00, ..., 1.375e+03, 8.000e+01,
#         9.500e+01],
#        ...,
#        [5.392e+03, 3.800e+01, 2.190e+00, ..., 1.375e+03, 1.600e+02,
#         1.740e+02],
#        [7.983e+03, 1.080e+02, 3.840e+00, ..., 1.375e+03, 7.000e+01,
#         9.400e+01],
#        [3.696e+03, 5.000e+01, 1.870e+00, ..., 1.375e+03, 1.060e+02,
#         1.210e+02]])

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.4213534 , -0.49709635, -0.35660792, ...,  0.2920417 ,
#          0.20851539,  0.12608133],
#        [-1.3640254 , -1.34824921,  0.91212997, ...,  0.2920417 ,
#          0.66166863,  0.58948925],
#        [-0.84151578, -0.70988457, -0.409472  , ...,  0.2920417 ,
#         -0.07470539, -0.16354863],
#        ...,
#        [ 0.38306004, -0.79499985,  0.05573189, ...,  0.2920417 ,
#          2.19106084,  2.12452802],
#        [ 1.54613773,  2.18403513,  1.80024649, ...,  0.2920417 ,
#         -0.35792617, -0.19251163],
#        [-0.37825983, -0.28430814, -0.28259821, ...,  0.2920417 ,
#          0.66166863,  0.58948925]])

# %%
X_test_scaled
# Out:
# array([[-0.76430646, -0.62476928, -0.26145258, ...,  0.2920417 ,
#          0.94488941,  0.58948925],
#        [ 1.54613773,  0.99242114, -0.409472  , ...,  0.2920417 ,
#         -0.10302747,  0.41571128],
#        [-0.96002312, -0.70988457, -0.56806423, ...,  0.2920417 ,
#         -0.21631578, -0.30836361],
#        ...,
#        [-0.82535569, -0.88011514, -0.99097686, ...,  0.2920417 ,
#          0.066905  , -0.01873365],
#        [-0.96002312, -0.70988457, -0.67379239, ...,  0.2920417 ,
#         -2.17053915, -2.3068103 ],
#        [ 1.54613773,  1.41799757, -0.1451516 , ...,  0.2920417 ,
#          0.18019331,  0.09711833]])

# %%
y_train
# Out:
# array([0, 1, 1, ..., 1, 3, 3], dtype=int64)

# %%
y_test
# Out:
# array([1, 0, 2, 3, 0, 4, 3, 0, 3, 3, 2, 3, 4, 4, 0, 4, 3, 3, 2, 2, 1, 4,
#        2, 4, 4, 0, 3, 0, 3, 4, 1, 2, 2, 3, 1, 3, 3, 4, 3, 0, 4, 4, 4, 1,
#        2, 3, 0, 4, 1, 3, 1, 2, 4, 3, 0, 4, 4, 1, 3, 4, 1, 0, 1, 2, 4, 1,
#        0, 1, 0, 3, 1, 2, 4, 4, 3, 3, 2, 3, 2, 1, 1, 2, 2, 4, 3, 4, 0, 4,
#        4, 0, 0, 3, 4, 0, 3, 1, 1, 1, 0, 1, 4, 0, 4, 2, 1, 0, 1, 0, 1, 0,
#        2, 3, 1, 0, 4, 1, 2, 0, 0, 1, 1, 1, 4, 0, 0, 3, 2, 1, 3, 1, 0, 2,
#        3, 1, 3, 0, 2, 0, 1, 1, 2, 4, 2, 0, 1, 3, 3, 4, 3, 1, 2, 2, 2, 2,
#        2, 4, 0, 0, 0, 2, 0, 1, 1, 3, 2, 1, 3, 3, 0, 3, 3, 0, 4, 2, 0, 3,
#        2, 3, 2, 1, 2, 1, 3, 4, 2, 4, 0, 0, 3, 3, 0, 3, 2, 0, 2, 0, 2, 0,
#        2, 1, 1, 4, 4, 4, 2, 1, 1, 4, 1, 3, 3, 0, 2, 0, 0, 4, 4, 4, 4, 0,
#        3, 1, 1, 2, 1, 0, 3, 4, 0, 0, 3, 2, 0, 0, 3, 1, 2, 4, 4, 4, 3, 2,
#        4, 3, 1, 3, 3, 3, 3, 3, 1, 0, 0, 1, 0, 2, 2, 2, 1, 1, 4, 2, 1, 4,
#        4, 3, 1, 0, 0, 1, 0, 3, 2, 3, 4, 3, 4, 0, 0, 0, 0, 2, 3, 2, 1, 1,
#        1, 1, 3, 4, 0, 0, 3, 3, 0, 1, 0, 0, 3, 3, 4, 3, 4, 4, 0, 2, 0, 0,
#        1, 2, 0, 2, 1, 2, 0, 2, 4, 1, 4, 1, 0, 3, 0, 3, 3, 1, 3, 0, 1, 4,
#        1, 1, 3, 4, 0, 2, 2, 4, 3, 1, 4, 2, 4, 1, 1, 3, 0, 1, 2, 0, 0, 3,
#        1, 2, 3, 2, 3, 0, 2, 0, 1, 0, 0, 0, 4, 1, 3, 1, 2, 2, 3, 3, 0, 1,
#        2, 0, 4, 1, 4, 0, 3, 3, 3, 4, 0, 1, 1, 2, 1, 4, 2, 0, 4, 4, 3, 1,
#        2, 0, 0, 1, 0, 1, 3, 0, 4, 0, 0, 4, 4, 2, 0, 3, 4, 1, 4, 3, 4, 4,
#        4, 3, 4, 1, 3, 0, 3, 3, 0, 1, 4, 4, 3, 2, 0, 0, 4, 4, 4, 4, 0, 0,
#        1, 0, 2, 4, 3, 3, 3, 1, 0, 1, 2, 2, 1, 1, 3, 3, 2, 3, 2, 3, 1, 2,
#        4, 2, 0, 0, 1, 2, 1, 2, 1, 0, 2, 4, 2, 3, 3, 2, 1, 0, 3, 3, 1, 2,
#        3, 2, 1, 4, 1, 3, 4, 3, 3, 2, 4, 1, 0, 1, 3, 0, 2, 0, 2, 4, 3, 1,
#        0, 4, 4, 2, 3, 0, 3, 2, 4, 4, 4, 1, 4, 1, 3, 3, 4, 0, 3, 2, 4, 1,
#        3, 4, 1, 2, 3, 4, 3, 4, 0, 0, 3, 0, 4, 2, 4, 2, 4, 0, 2, 2, 4, 1,
#        4, 0, 2, 2, 3, 1, 0, 0, 3, 3, 3, 3, 3, 3, 4, 1, 4, 3, 2, 3, 1, 3,
#        4, 1, 2, 0, 3, 1, 1, 2, 3, 4, 3, 1, 2, 2, 0, 2, 4, 4, 2, 4, 3, 0,
#        4, 4, 4, 0, 1, 1, 2, 1, 1, 4, 1, 3, 1, 4, 4, 3, 0, 1, 4, 4, 1, 1,
#        2, 2, 2, 2, 1, 2, 4, 4, 4, 1, 1, 2, 2, 0, 1, 2, 4, 1, 0, 2, 1, 4,
#        3, 2, 1, 4, 2, 3, 1, 2, 3, 4, 2, 3, 0, 3, 4, 1, 0, 3, 3, 1, 4],
#       dtype=int64)

# %%
model = XGBClassifier(random_state=0, n_estimators=100, objective='multi:softmax')

# %%
parameters = {'max_depth': np.arange(3,10,1),
              'learning rate': np.arange(0.05,0.3,0.03),
              'n_estimators':np.arange(100,1000,100),
              'min_child_weight': np.arange(1,4,1),
              'gamma':np.arange(0,50,2),
              'subsample':np.arange(0.5,0.9,0.1),
              'colsample_bytree':np.arange(0.5,0.9,0.1)
             }

# %%
randm = RandomizedSearchCV(estimator=model, param_distributions = parameters, cv = 5, n_iter = 50, 
                           n_jobs=-1, scoring='accuracy')

# %%
randm.fit(X_train_scaled, y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1, gamma=0,
#                                            learning_rate=0.1, max_delta_step=0,
#                                            max_depth=3, min_child_weight=1,
#                                            missing=None, n_estimators=100,
#                                            n_jobs=1, nthread=None,
#                                            objective='multi:softmax',
#                                            random_state=0, reg_alpha=0,
#                                            reg_lambda=1, scal...
#        34, 36, 38, 40, 42, 44, 46, 48]),
#                                         'learning rate': array([0.05, 0.08, 0.11, 0.14, 0.17, 0.2 , 0.23, 0.26, 0.29]),
#                                         'max_depth': array([3, 4, 5, 6, 7, 8, 9]),
#                                         'min_child_weight': array([1, 2, 3]),
#                                         'n_estimators': array([100, 200, 300, 400, 500, 600, 700, 800, 900]),
#                                         'subsample': array([0.5, 0.6, 0.7, 0.8])},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='accuracy', verbose=0)

# %%
randm.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.7, gamma=0,
#               learning rate=0.14, learning_rate=0.1, max_delta_step=0,
#               max_depth=5, min_child_weight=1, missing=None, n_estimators=800,
#               n_jobs=1, nthread=None, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=None, silent=None, subsample=0.5, verbosity=1)

# %%
randm.best_score_
# Out:
# 0.6494824909435917

# %%
randm.best_params_
# Out:
# {'subsample': 0.5,
#  'n_estimators': 800,
#  'min_child_weight': 1,
#  'max_depth': 5,
#  'learning rate': 0.14,
#  'gamma': 0,
#  'colsample_bytree': 0.7}

# %% [markdown]
# {'subsample': 0.7999999999999999,
#  'n_estimators': 800,
#  'min_child_weight': 2,
#  'max_depth': 4,
#  'learning rate': 0.05,
#  'gamma': 0,
#  'colsample_bytree': 0.7}

# %% [markdown]
# ### Save the Model

# %%
filename = 'modelbrooklyn.sav'
dump(xgbmodel,open(filename,'wb'))
