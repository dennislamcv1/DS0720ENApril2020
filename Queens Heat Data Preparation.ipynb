# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# The goal of this exercise is to do Model Development and Validation to find the answer to the Question 4 of the problem statement:
#
# Can a predictive model be built for future prediction of the possibility of complaints of the specific type that you identified in response to Question 1?

# %% [markdown]
# Using the best model, you need to predict the number of future complaints (of the Complaint Type that you decided to focus on in Question 1).

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %matplotlib inline
sns.set_style('darkgrid')
sns.set(font_scale=1.5)


import feature_engine.missing_data_imputers as mdi
from feature_engine.outlier_removers import Winsorizer

import warnings
warnings.filterwarnings('ignore')


pd.options.display.max_columns= None
#pd.options.display.max_rows = None

# %% [markdown]
# ### Data Exploration

# %%
df = pd.read_csv("heat.csv")

# %%
df
# Out:
#           ComplaintType  Zipcode              Street    Borough
# 0        HEAT/HOT WATER  10019.0    WEST   52 STREET  MANHATTAN
# 1        HEAT/HOT WATER  11372.0           37 AVENUE     QUEENS
# 2        HEAT/HOT WATER  10458.0  SOUTHERN BOULEVARD      BRONX
# 3        HEAT/HOT WATER  10456.0       MORRIS AVENUE      BRONX
# 4        HEAT/HOT WATER  11372.0           81 STREET     QUEENS
# ...                 ...      ...                 ...        ...
# 1847750  HEAT/HOT WATER  10029.0    EAST  108 STREET  MANHATTAN
# 1847751  HEAT/HOT WATER  10029.0    EAST  108 STREET  MANHATTAN
# 1847752  HEAT/HOT WATER  10461.0  BRUCKNER BOULEVARD      BRONX
# 1847753  HEAT/HOT WATER  10034.0      SHERMAN AVENUE  MANHATTAN
# 1847754  HEAT/HOT WATER  10467.0  WEST GUN HILL ROAD      BRONX
#
# [1847755 rows x 4 columns]

# %%
df.drop(['ComplaintType', 'Zipcode'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Street', 'Borough'], dtype='object')

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ### Segment Heat/Hot Water Cases for QUEENS

# %%
df['Borough'].value_counts()
# Out:
# BRONX            600147
# BROOKLYN         569310
# MANHATTAN        418432
# QUEENS           241660
# STATEN ISLAND     18206
# Name: Borough, dtype: int64

# %%
queen = df[df['Borough'] == 'QUEENS']

# %%
queen
# Out:
#                     Street Borough
# 1                37 AVENUE  QUEENS
# 4                81 STREET  QUEENS
# 27           SENECA AVENUE  QUEENS
# 29         ELMHURST AVENUE  QUEENS
# 33               49 STREET  QUEENS
# ...                    ...     ...
# 1847635          48 STREET  QUEENS
# 1847681  PERSHING CRESCENT  QUEENS
# 1847691          48 STREET  QUEENS
# 1847733          205 PLACE  QUEENS
# 1847735          88 STREET  QUEENS
#
# [241660 rows x 2 columns]

# %%
queen.reset_index(drop=True, inplace=True)

# %%
queen
# Out:
#                    Street Borough
# 0               37 AVENUE  QUEENS
# 1               81 STREET  QUEENS
# 2           SENECA AVENUE  QUEENS
# 3         ELMHURST AVENUE  QUEENS
# 4               49 STREET  QUEENS
# ...                   ...     ...
# 241655          48 STREET  QUEENS
# 241656  PERSHING CRESCENT  QUEENS
# 241657          48 STREET  QUEENS
# 241658          205 PLACE  QUEENS
# 241659          88 STREET  QUEENS
#
# [241660 rows x 2 columns]

# %%
df2 = pd.read_csv("queensclasstrain.csv")

# %%
df2
# Out:
#         BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# 1         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# 2         5569.0       94.0      2.16      2.0       5.0   9580.0     100.0
# 3         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# 4         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# ...          ...        ...       ...      ...       ...      ...       ...
# 324578    1760.0       39.0      0.61      2.0       2.0   5700.0     100.0
# 324579    1760.0       39.0      0.61      2.0       2.0   7650.0     100.0
# 324580    1760.0       39.0      0.61      2.0       2.0   6200.0     100.0
# 324581    5569.0       40.0      0.13      2.0       2.0   9580.0     100.0
# 324582    5569.0       39.0      1.48      2.0       2.0   9580.0     100.0
#
#         NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 1            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 2            1.0        4.0      1680.0   1600.0       1.8      1500.0   0.0
# 3            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 4            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# ...          ...        ...         ...      ...       ...         ...   ...
# 324578       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 324579       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 324580       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 324581       5.0        1.0      1680.0   4584.0       0.9      1500.0  68.0
# 324582       1.0        1.0      1680.0   1600.0       0.6      1500.0  77.0
#
#         Period  ComplaintType
# 0         85.0              0
# 1         85.0              4
# 2          9.0              3
# 3         85.0              1
# 4         85.0              1
# ...        ...            ...
# 324578    85.0              0
# 324579    85.0              1
# 324580    85.0              4
# 324581    82.0              2
# 324582    91.0              1
#
# [324583 rows x 16 columns]

# %%
heat = df2[df2['ComplaintType'] == 0]

# %%
heat
# Out:
#         BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# 9         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# 12        5569.0       70.0      2.16      2.0       5.0   9580.0     100.0
# 13        5569.0       94.0      2.16      2.0       5.0   9580.0     100.0
# 17        5569.0       75.0      0.34      2.0       5.0   9580.0     100.0
# ...          ...        ...       ...      ...       ...      ...       ...
# 324574    1760.0       39.0      0.61      2.0       2.0   1350.0      50.0
# 324575    1760.0       39.0      0.61      2.0       2.0   7000.0     100.0
# 324576    1760.0       39.0      0.61      2.0       2.0   6000.0     100.0
# 324577    1760.0       39.0      0.61      2.0       2.0   5100.0      90.0
# 324578    1760.0       39.0      0.61      2.0       2.0   5700.0     100.0
#
#         NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 9            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 12           2.0        4.0      1680.0   4584.0       1.8      1500.0  -7.0
# 13           1.0        4.0      1680.0   4584.0       1.8      1500.0   0.0
# 17           5.0        2.0      1680.0   1600.0       0.6      1500.0  48.0
# ...          ...        ...         ...      ...       ...         ...   ...
# 324574       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 324575       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 324576       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 324577       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 324578       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
#
#         Period  ComplaintType
# 0         85.0              0
# 9         85.0              0
# 12         7.0              0
# 13         7.0              0
# 17        62.0              0
# ...        ...            ...
# 324574    85.0              0
# 324575    85.0              0
# 324576    85.0              0
# 324577    85.0              0
# 324578    85.0              0
#
# [122516 rows x 16 columns]

# %%
heat.reset_index(drop=True, inplace=True)

# %%
heat
# Out:
#         BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# 1         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# 2         5569.0       70.0      2.16      2.0       5.0   9580.0     100.0
# 3         5569.0       94.0      2.16      2.0       5.0   9580.0     100.0
# 4         5569.0       75.0      0.34      2.0       5.0   9580.0     100.0
# ...          ...        ...       ...      ...       ...      ...       ...
# 122511    1760.0       39.0      0.61      2.0       2.0   1350.0      50.0
# 122512    1760.0       39.0      0.61      2.0       2.0   7000.0     100.0
# 122513    1760.0       39.0      0.61      2.0       2.0   6000.0     100.0
# 122514    1760.0       39.0      0.61      2.0       2.0   5100.0      90.0
# 122515    1760.0       39.0      0.61      2.0       2.0   5700.0     100.0
#
#         NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 1            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 2            2.0        4.0      1680.0   4584.0       1.8      1500.0  -7.0
# 3            1.0        4.0      1680.0   4584.0       1.8      1500.0   0.0
# 4            5.0        2.0      1680.0   1600.0       0.6      1500.0  48.0
# ...          ...        ...         ...      ...       ...         ...   ...
# 122511       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122512       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122513       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122514       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122515       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
#
#         Period  ComplaintType
# 0         85.0              0
# 1         85.0              0
# 2          7.0              0
# 3          7.0              0
# 4         62.0              0
# ...        ...            ...
# 122511    85.0              0
# 122512    85.0              0
# 122513    85.0              0
# 122514    85.0              0
# 122515    85.0              0
#
# [122516 rows x 16 columns]

# %%
heat.shape
# Out:
# (122516, 16)

# %%
quheat = queen.sample(n=122516, random_state=0)

# %%
quheat
# Out:
#                        Street Borough
# 50333        BEACH 100 STREET  QUEENS
# 37191        LINDEN BOULEVARD  QUEENS
# 159237              43 STREET  QUEENS
# 77415   YELLOWSTONE BOULEVARD  QUEENS
# 123114        ELMHURST AVENUE  QUEENS
# ...                       ...     ...
# 98987               65 STREET  QUEENS
# 222789             169 STREET  QUEENS
# 229528    SHORE FRONT PARKWAY  QUEENS
# 211787             163 STREET  QUEENS
# 3178          ELMHURST AVENUE  QUEENS
#
# [122516 rows x 2 columns]

# %%
quheat.reset_index(drop=True,inplace=True)

# %%
quheat
# Out:
#                        Street Borough
# 0            BEACH 100 STREET  QUEENS
# 1            LINDEN BOULEVARD  QUEENS
# 2                   43 STREET  QUEENS
# 3       YELLOWSTONE BOULEVARD  QUEENS
# 4             ELMHURST AVENUE  QUEENS
# ...                       ...     ...
# 122511              65 STREET  QUEENS
# 122512             169 STREET  QUEENS
# 122513    SHORE FRONT PARKWAY  QUEENS
# 122514             163 STREET  QUEENS
# 122515        ELMHURST AVENUE  QUEENS
#
# [122516 rows x 2 columns]

# %%
df3 = pd.concat([heat,quheat],axis=1)

# %%
df3
# Out:
#         BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# 1         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# 2         5569.0       70.0      2.16      2.0       5.0   9580.0     100.0
# 3         5569.0       94.0      2.16      2.0       5.0   9580.0     100.0
# 4         5569.0       75.0      0.34      2.0       5.0   9580.0     100.0
# ...          ...        ...       ...      ...       ...      ...       ...
# 122511    1760.0       39.0      0.61      2.0       2.0   1350.0      50.0
# 122512    1760.0       39.0      0.61      2.0       2.0   7000.0     100.0
# 122513    1760.0       39.0      0.61      2.0       2.0   6000.0     100.0
# 122514    1760.0       39.0      0.61      2.0       2.0   5100.0      90.0
# 122515    1760.0       39.0      0.61      2.0       2.0   5700.0     100.0
#
#         NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 1            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 2            2.0        4.0      1680.0   4584.0       1.8      1500.0  -7.0
# 3            1.0        4.0      1680.0   4584.0       1.8      1500.0   0.0
# 4            5.0        2.0      1680.0   1600.0       0.6      1500.0  48.0
# ...          ...        ...         ...      ...       ...         ...   ...
# 122511       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122512       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122513       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122514       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122515       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
#
#         Period  ComplaintType                 Street Borough
# 0         85.0              0       BEACH 100 STREET  QUEENS
# 1         85.0              0       LINDEN BOULEVARD  QUEENS
# 2          7.0              0              43 STREET  QUEENS
# 3          7.0              0  YELLOWSTONE BOULEVARD  QUEENS
# 4         62.0              0        ELMHURST AVENUE  QUEENS
# ...        ...            ...                    ...     ...
# 122511    85.0              0              65 STREET  QUEENS
# 122512    85.0              0             169 STREET  QUEENS
# 122513    85.0              0    SHORE FRONT PARKWAY  QUEENS
# 122514    85.0              0             163 STREET  QUEENS
# 122515    85.0              0        ELMHURST AVENUE  QUEENS
#
# [122516 rows x 18 columns]

# %%
df3.columns
# Out:
# Index(['BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'LotArea',
#        'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea',
#        'ResidFAR', 'RetailArea', 'Age', 'Period', 'ComplaintType', 'Street',
#        'Borough'],
#       dtype='object')

# %%
df3.drop(['ComplaintType', 'Street'],axis=1,inplace=True)

# %%
df3
# Out:
#         BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# 1         1760.0       39.0      0.61      2.0       5.0   9580.0     100.0
# 2         5569.0       70.0      2.16      2.0       5.0   9580.0     100.0
# 3         5569.0       94.0      2.16      2.0       5.0   9580.0     100.0
# 4         5569.0       75.0      0.34      2.0       5.0   9580.0     100.0
# ...          ...        ...       ...      ...       ...      ...       ...
# 122511    1760.0       39.0      0.61      2.0       2.0   1350.0      50.0
# 122512    1760.0       39.0      0.61      2.0       2.0   7000.0     100.0
# 122513    1760.0       39.0      0.61      2.0       2.0   6000.0     100.0
# 122514    1760.0       39.0      0.61      2.0       2.0   5100.0      90.0
# 122515    1760.0       39.0      0.61      2.0       2.0   5700.0     100.0
#
#         NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 1            1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 2            2.0        4.0      1680.0   4584.0       1.8      1500.0  -7.0
# 3            1.0        4.0      1680.0   4584.0       1.8      1500.0   0.0
# 4            5.0        2.0      1680.0   1600.0       0.6      1500.0  48.0
# ...          ...        ...         ...      ...       ...         ...   ...
# 122511       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122512       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122513       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122514       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 122515       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
#
#         Period Borough
# 0         85.0  QUEENS
# 1         85.0  QUEENS
# 2          7.0  QUEENS
# 3          7.0  QUEENS
# 4         62.0  QUEENS
# ...        ...     ...
# 122511    85.0  QUEENS
# 122512    85.0  QUEENS
# 122513    85.0  QUEENS
# 122514    85.0  QUEENS
# 122515    85.0  QUEENS
#
# [122516 rows x 16 columns]

# %%
df3.duplicated(keep='first').sum()
# Out:
# 24703

# %%
df3.drop_duplicates(keep='first',ignore_index=True, inplace=True)

# %%
df3
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0        1760.0       39.0      0.61      2.0       5.0   9580.0    100.00
# 1        5569.0       70.0      2.16      2.0       5.0   9580.0    100.00
# 2        5569.0       94.0      2.16      2.0       5.0   9580.0    100.00
# 3        5569.0       75.0      0.34      2.0       5.0   9580.0    100.00
# 4        1760.0       39.0      0.61      2.0       5.0   6310.0     51.18
# ...         ...        ...       ...      ...       ...      ...       ...
# 97808    1760.0       39.0      0.61      2.0       2.0   4375.0     60.00
# 97809    1760.0       39.0      0.61      2.0       2.0   5642.0    100.00
# 97810    1760.0       39.0      0.61      2.0       2.0   1350.0     50.00
# 97811    1760.0       39.0      0.61      2.0       2.0   5100.0     90.00
# 97812    1760.0       39.0      0.61      2.0       2.0   5700.0    100.00
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0           1.0        2.0      1680.0   1600.0       1.8      1500.0  71.0
# 1           2.0        4.0      1680.0   4584.0       1.8      1500.0  -7.0
# 2           1.0        4.0      1680.0   4584.0       1.8      1500.0   0.0
# 3           5.0        2.0      1680.0   1600.0       0.6      1500.0  48.0
# 4           1.0        2.0      1680.0   1600.0       0.6      1500.0  71.0
# ...         ...        ...         ...      ...       ...         ...   ...
# 97808       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 97809       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 97810       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 97811       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
# 97812       1.0        2.0      1680.0   1600.0       0.9      1500.0  71.0
#
#        Period Borough
# 0        85.0  QUEENS
# 1         7.0  QUEENS
# 2         7.0  QUEENS
# 3        62.0  QUEENS
# 4        85.0  QUEENS
# ...       ...     ...
# 97808    85.0  QUEENS
# 97809    85.0  QUEENS
# 97810    85.0  QUEENS
# 97811    85.0  QUEENS
# 97812    85.0  QUEENS
#
# [97813 rows x 16 columns]

# %%
#Save to CSV
#df3.to_csv("queensheat.csv",index=False)
