# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# The goal of this exercise is to do Model Development and Validation to find the answer to the Question 4 of the problem statement:
#
# Can a predictive model be built for future prediction of the possibility of complaints of the specific type that you identified in response to Question 1?

# %% [markdown]
# Using the best model, you need to predict the number of future complaints (of the Complaint Type that you decided to focus on in Question 1).

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %matplotlib inline
sns.set_style('darkgrid')
sns.set(font_scale=1.5)


import feature_engine.missing_data_imputers as mdi
from feature_engine.outlier_removers import Winsorizer

import warnings
warnings.filterwarnings('ignore')


pd.options.display.max_columns= None
#pd.options.display.max_rows = None

# %% [markdown]
# ### Data Exploration

# %%
df = pd.read_csv("heat.csv")

# %%
df
# Out:
#           ComplaintType  Zipcode              Street    Borough
# 0        HEAT/HOT WATER  10019.0    WEST   52 STREET  MANHATTAN
# 1        HEAT/HOT WATER  11372.0           37 AVENUE     QUEENS
# 2        HEAT/HOT WATER  10458.0  SOUTHERN BOULEVARD      BRONX
# 3        HEAT/HOT WATER  10456.0       MORRIS AVENUE      BRONX
# 4        HEAT/HOT WATER  11372.0           81 STREET     QUEENS
# ...                 ...      ...                 ...        ...
# 1847750  HEAT/HOT WATER  10029.0    EAST  108 STREET  MANHATTAN
# 1847751  HEAT/HOT WATER  10029.0    EAST  108 STREET  MANHATTAN
# 1847752  HEAT/HOT WATER  10461.0  BRUCKNER BOULEVARD      BRONX
# 1847753  HEAT/HOT WATER  10034.0      SHERMAN AVENUE  MANHATTAN
# 1847754  HEAT/HOT WATER  10467.0  WEST GUN HILL ROAD      BRONX
#
# [1847755 rows x 4 columns]

# %%
df.drop(['ComplaintType', 'Zipcode'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Street', 'Borough'], dtype='object')

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ### Segment Heat/Hot Water Cases for Bronx

# %%
df['Borough'].value_counts()
# Out:
# BRONX            600147
# BROOKLYN         569310
# MANHATTAN        418432
# QUEENS           241660
# STATEN ISLAND     18206
# Name: Borough, dtype: int64

# %%
bronx = df[df['Borough'] == 'BRONX']

# %%
bronx
# Out:
#                       Street Borough
# 2         SOUTHERN BOULEVARD   BRONX
# 3              MORRIS AVENUE   BRONX
# 6               ALDUS STREET   BRONX
# 12            BOYNTON AVENUE   BRONX
# 18       KINGSBRIDGE TERRACE   BRONX
# ...                      ...     ...
# 1847747    WOODYCREST AVENUE   BRONX
# 1847748     EAST  242 STREET   BRONX
# 1847749    BAINBRIDGE AVENUE   BRONX
# 1847752   BRUCKNER BOULEVARD   BRONX
# 1847754   WEST GUN HILL ROAD   BRONX
#
# [600147 rows x 2 columns]

# %%
bronx.reset_index(drop=True, inplace=True)

# %%
bronx
# Out:
#                      Street Borough
# 0        SOUTHERN BOULEVARD   BRONX
# 1             MORRIS AVENUE   BRONX
# 2              ALDUS STREET   BRONX
# 3            BOYNTON AVENUE   BRONX
# 4       KINGSBRIDGE TERRACE   BRONX
# ...                     ...     ...
# 600142    WOODYCREST AVENUE   BRONX
# 600143     EAST  242 STREET   BRONX
# 600144    BAINBRIDGE AVENUE   BRONX
# 600145   BRUCKNER BOULEVARD   BRONX
# 600146   WEST GUN HILL ROAD   BRONX
#
# [600147 rows x 2 columns]

# %%
df2 = pd.read_csv("bronxclasstrain.csv")

# %%
df2
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0        2340.0       46.0      0.90      2.0       6.5  10400.0     125.0
# 1         752.0       16.0      0.05      2.0       6.5  10400.0     100.0
# 2        7858.0      112.0      1.13      2.0       6.5  10400.0     125.0
# 3        7858.0       85.0      3.08      2.0       6.5   2500.0     100.0
# 4        7858.0       70.0      3.08      2.0       6.5   1875.0      75.0
# ...         ...        ...       ...      ...       ...      ...       ...
# 89705    2340.0       46.0      0.90      2.0       2.0    323.0     125.0
# 89706    2340.0       46.0      0.90      2.0       2.0   2513.0     125.0
# 89707    2340.0       46.0      0.90      2.0       2.0   2513.0     100.0
# 89708    2340.0       46.0      0.90      2.0       6.5   2513.0     100.0
# 89709    2340.0       46.0      0.90      2.0       2.0   2513.0     100.0
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0           1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# 1           1.0        1.0       272.0   2000.0      6.02      2458.0  63.0
# 2           1.0        2.0      2628.0   2000.0      6.02      2458.0  69.0
# 3           1.0        5.0      2628.0   6034.0      6.02      2458.0  70.0
# 4           1.0        5.0      2628.0   6034.0      6.02      1719.0  89.0
# ...         ...        ...         ...      ...       ...         ...   ...
# 89705       1.0        2.0      2628.0   2000.0      0.90      2458.0  65.0
# 89706       1.0        2.0      2628.0   2000.0      0.90      2458.0  65.0
# 89707       1.0        2.0      2628.0   2000.0      1.25      2458.0  65.0
# 89708       1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# 89709       1.0        2.0      2628.0   2000.0      1.25      2458.0  65.0
#
#        Period  ComplaintType
# 0        85.0              0
# 1        89.0              1
# 2        89.0              0
# 3        89.0              0
# 4       100.0              0
# ...       ...            ...
# 89705    85.0              0
# 89706    85.0              3
# 89707    85.0              0
# 89708    85.0              1
# 89709    85.0              0
#
# [89710 rows x 16 columns]

# %%
heat = df2[df2['ComplaintType'] == 0]

# %%
heat
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0        2340.0       46.0      0.90      2.0       6.5  10400.0    125.00
# 2        7858.0      112.0      1.13      2.0       6.5  10400.0    125.00
# 3        7858.0       85.0      3.08      2.0       6.5   2500.0    100.00
# 4        7858.0       70.0      3.08      2.0       6.5   1875.0     75.00
# 5        2340.0       46.0      0.90      2.0       6.5  10400.0    100.00
# ...         ...        ...       ...      ...       ...      ...       ...
# 89698    1512.0       28.0      0.39      2.0       1.0   3891.0    109.08
# 89703    2340.0       46.0      0.90      2.0       2.0  10400.0    125.00
# 89705    2340.0       46.0      0.90      2.0       2.0    323.0    125.00
# 89707    2340.0       46.0      0.90      2.0       2.0   2513.0    100.00
# 89709    2340.0       46.0      0.90      2.0       2.0   2513.0    100.00
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0           1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# 2           1.0        2.0      2628.0   2000.0      6.02      2458.0  69.0
# 3           1.0        5.0      2628.0   6034.0      6.02      2458.0  70.0
# 4           1.0        5.0      2628.0   6034.0      6.02      1719.0  89.0
# 5           1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# ...         ...        ...         ...      ...       ...         ...   ...
# 89698       1.0        2.0      2628.0   1512.0      0.50      2458.0  60.0
# 89703       1.0        2.0      2628.0   2000.0      0.90      2458.0  65.0
# 89705       1.0        2.0      2628.0   2000.0      0.90      2458.0  65.0
# 89707       1.0        2.0      2628.0   2000.0      1.25      2458.0  65.0
# 89709       1.0        2.0      2628.0   2000.0      1.25      2458.0  65.0
#
#        Period  ComplaintType
# 0        85.0              0
# 2        89.0              0
# 3        89.0              0
# 4       100.0              0
# 5        85.0              0
# ...       ...            ...
# 89698    80.0              0
# 89703    85.0              0
# 89705    85.0              0
# 89707    85.0              0
# 89709    85.0              0
#
# [33664 rows x 16 columns]

# %%
heat.reset_index(drop=True, inplace=True)

# %%
heat
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0        2340.0       46.0      0.90      2.0       6.5  10400.0    125.00
# 1        7858.0      112.0      1.13      2.0       6.5  10400.0    125.00
# 2        7858.0       85.0      3.08      2.0       6.5   2500.0    100.00
# 3        7858.0       70.0      3.08      2.0       6.5   1875.0     75.00
# 4        2340.0       46.0      0.90      2.0       6.5  10400.0    100.00
# ...         ...        ...       ...      ...       ...      ...       ...
# 33659    1512.0       28.0      0.39      2.0       1.0   3891.0    109.08
# 33660    2340.0       46.0      0.90      2.0       2.0  10400.0    125.00
# 33661    2340.0       46.0      0.90      2.0       2.0    323.0    125.00
# 33662    2340.0       46.0      0.90      2.0       2.0   2513.0    100.00
# 33663    2340.0       46.0      0.90      2.0       2.0   2513.0    100.00
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0           1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# 1           1.0        2.0      2628.0   2000.0      6.02      2458.0  69.0
# 2           1.0        5.0      2628.0   6034.0      6.02      2458.0  70.0
# 3           1.0        5.0      2628.0   6034.0      6.02      1719.0  89.0
# 4           1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# ...         ...        ...         ...      ...       ...         ...   ...
# 33659       1.0        2.0      2628.0   1512.0      0.50      2458.0  60.0
# 33660       1.0        2.0      2628.0   2000.0      0.90      2458.0  65.0
# 33661       1.0        2.0      2628.0   2000.0      0.90      2458.0  65.0
# 33662       1.0        2.0      2628.0   2000.0      1.25      2458.0  65.0
# 33663       1.0        2.0      2628.0   2000.0      1.25      2458.0  65.0
#
#        Period  ComplaintType
# 0        85.0              0
# 1        89.0              0
# 2        89.0              0
# 3       100.0              0
# 4        85.0              0
# ...       ...            ...
# 33659    80.0              0
# 33660    85.0              0
# 33661    85.0              0
# 33662    85.0              0
# 33663    85.0              0
#
# [33664 rows x 16 columns]

# %%
heat.shape
# Out:
# (33664, 16)

# %%
brheat = bronx.sample(n=33664, random_state=0)

# %%
brheat
# Out:
#                     Street Borough
# 274458    CARPENTER AVENUE   BRONX
# 302785       MT HOPE PLACE   BRONX
# 177600     EAST 169 STREET   BRONX
# 509664  SOUTHERN BOULEVARD   BRONX
# 173531      CROTONA AVENUE   BRONX
# ...                    ...     ...
# 238741       MARION AVENUE   BRONX
# 501873      WALLACE AVENUE   BRONX
# 560034    GILLESPIE AVENUE   BRONX
# 282084     EAST 241 STREET   BRONX
# 359837      BUCHANAN PLACE   BRONX
#
# [33664 rows x 2 columns]

# %%
brheat.reset_index(drop=True,inplace=True)

# %%
brheat
# Out:
#                    Street Borough
# 0        CARPENTER AVENUE   BRONX
# 1           MT HOPE PLACE   BRONX
# 2         EAST 169 STREET   BRONX
# 3      SOUTHERN BOULEVARD   BRONX
# 4          CROTONA AVENUE   BRONX
# ...                   ...     ...
# 33659       MARION AVENUE   BRONX
# 33660      WALLACE AVENUE   BRONX
# 33661    GILLESPIE AVENUE   BRONX
# 33662     EAST 241 STREET   BRONX
# 33663      BUCHANAN PLACE   BRONX
#
# [33664 rows x 2 columns]

# %%
df3 = pd.concat([heat,brheat],axis=1)

# %%
df3
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0        2340.0       46.0      0.90      2.0       6.5  10400.0    125.00
# 1        7858.0      112.0      1.13      2.0       6.5  10400.0    125.00
# 2        7858.0       85.0      3.08      2.0       6.5   2500.0    100.00
# 3        7858.0       70.0      3.08      2.0       6.5   1875.0     75.00
# 4        2340.0       46.0      0.90      2.0       6.5  10400.0    100.00
# ...         ...        ...       ...      ...       ...      ...       ...
# 33659    1512.0       28.0      0.39      2.0       1.0   3891.0    109.08
# 33660    2340.0       46.0      0.90      2.0       2.0  10400.0    125.00
# 33661    2340.0       46.0      0.90      2.0       2.0    323.0    125.00
# 33662    2340.0       46.0      0.90      2.0       2.0   2513.0    100.00
# 33663    2340.0       46.0      0.90      2.0       2.0   2513.0    100.00
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0           1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# 1           1.0        2.0      2628.0   2000.0      6.02      2458.0  69.0
# 2           1.0        5.0      2628.0   6034.0      6.02      2458.0  70.0
# 3           1.0        5.0      2628.0   6034.0      6.02      1719.0  89.0
# 4           1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# ...         ...        ...         ...      ...       ...         ...   ...
# 33659       1.0        2.0      2628.0   1512.0      0.50      2458.0  60.0
# 33660       1.0        2.0      2628.0   2000.0      0.90      2458.0  65.0
# 33661       1.0        2.0      2628.0   2000.0      0.90      2458.0  65.0
# 33662       1.0        2.0      2628.0   2000.0      1.25      2458.0  65.0
# 33663       1.0        2.0      2628.0   2000.0      1.25      2458.0  65.0
#
#        Period  ComplaintType              Street Borough
# 0        85.0              0    CARPENTER AVENUE   BRONX
# 1        89.0              0       MT HOPE PLACE   BRONX
# 2        89.0              0     EAST 169 STREET   BRONX
# 3       100.0              0  SOUTHERN BOULEVARD   BRONX
# 4        85.0              0      CROTONA AVENUE   BRONX
# ...       ...            ...                 ...     ...
# 33659    80.0              0       MARION AVENUE   BRONX
# 33660    85.0              0      WALLACE AVENUE   BRONX
# 33661    85.0              0    GILLESPIE AVENUE   BRONX
# 33662    85.0              0     EAST 241 STREET   BRONX
# 33663    85.0              0      BUCHANAN PLACE   BRONX
#
# [33664 rows x 18 columns]

# %%
df3.columns
# Out:
# Index(['BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'LotArea',
#        'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea',
#        'ResidFAR', 'RetailArea', 'Age', 'Period', 'ComplaintType', 'Street',
#        'Borough'],
#       dtype='object')

# %%
df3.drop(['ComplaintType', 'Street'],axis=1,inplace=True)

# %%
df3
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0        2340.0       46.0      0.90      2.0       6.5  10400.0    125.00
# 1        7858.0      112.0      1.13      2.0       6.5  10400.0    125.00
# 2        7858.0       85.0      3.08      2.0       6.5   2500.0    100.00
# 3        7858.0       70.0      3.08      2.0       6.5   1875.0     75.00
# 4        2340.0       46.0      0.90      2.0       6.5  10400.0    100.00
# ...         ...        ...       ...      ...       ...      ...       ...
# 33659    1512.0       28.0      0.39      2.0       1.0   3891.0    109.08
# 33660    2340.0       46.0      0.90      2.0       2.0  10400.0    125.00
# 33661    2340.0       46.0      0.90      2.0       2.0    323.0    125.00
# 33662    2340.0       46.0      0.90      2.0       2.0   2513.0    100.00
# 33663    2340.0       46.0      0.90      2.0       2.0   2513.0    100.00
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0           1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# 1           1.0        2.0      2628.0   2000.0      6.02      2458.0  69.0
# 2           1.0        5.0      2628.0   6034.0      6.02      2458.0  70.0
# 3           1.0        5.0      2628.0   6034.0      6.02      1719.0  89.0
# 4           1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# ...         ...        ...         ...      ...       ...         ...   ...
# 33659       1.0        2.0      2628.0   1512.0      0.50      2458.0  60.0
# 33660       1.0        2.0      2628.0   2000.0      0.90      2458.0  65.0
# 33661       1.0        2.0      2628.0   2000.0      0.90      2458.0  65.0
# 33662       1.0        2.0      2628.0   2000.0      1.25      2458.0  65.0
# 33663       1.0        2.0      2628.0   2000.0      1.25      2458.0  65.0
#
#        Period Borough
# 0        85.0   BRONX
# 1        89.0   BRONX
# 2        89.0   BRONX
# 3       100.0   BRONX
# 4        85.0   BRONX
# ...       ...     ...
# 33659    80.0   BRONX
# 33660    85.0   BRONX
# 33661    85.0   BRONX
# 33662    85.0   BRONX
# 33663    85.0   BRONX
#
# [33664 rows x 16 columns]

# %%
df3.duplicated(keep='first').sum()
# Out:
# 4677

# %%
df3.drop_duplicates(keep='first',ignore_index=True, inplace=True)

# %%
df3
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0        2340.0       46.0      0.90      2.0       6.5  10400.0    125.00
# 1        7858.0      112.0      1.13      2.0       6.5  10400.0    125.00
# 2        7858.0       85.0      3.08      2.0       6.5   2500.0    100.00
# 3        7858.0       70.0      3.08      2.0       6.5   1875.0     75.00
# 4        2340.0       46.0      0.90      2.0       6.5  10400.0    100.00
# ...         ...        ...       ...      ...       ...      ...       ...
# 28982    2340.0       46.0      0.90      2.0       1.0   2701.0    106.25
# 28983    1666.0       30.0      0.38      2.0       1.0   4360.0    122.25
# 28984    1720.0       30.0      0.20      2.0       1.0   8400.0    112.00
# 28985    1512.0       28.0      0.39      2.0       1.0   3891.0    109.08
# 28986    2340.0       46.0      0.90      2.0       2.0    323.0    125.00
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0           1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# 1           1.0        2.0      2628.0   2000.0      6.02      2458.0  69.0
# 2           1.0        5.0      2628.0   6034.0      6.02      2458.0  70.0
# 3           1.0        5.0      2628.0   6034.0      6.02      1719.0  89.0
# 4           1.0        2.0      2628.0   2000.0      6.02      2458.0  65.0
# ...         ...        ...         ...      ...       ...         ...   ...
# 28982       1.0        2.0      2628.0   2000.0      0.50      2458.0  65.0
# 28983       1.0        2.0      2628.0   1666.0      0.50      2458.0  60.0
# 28984       1.0        2.0      2628.0   1720.0      0.50      2458.0  60.0
# 28985       1.0        2.0      2628.0   1512.0      0.50      2458.0  60.0
# 28986       1.0        2.0      2628.0   2000.0      0.90      2458.0  65.0
#
#        Period Borough
# 0        85.0   BRONX
# 1        89.0   BRONX
# 2        89.0   BRONX
# 3       100.0   BRONX
# 4        85.0   BRONX
# ...       ...     ...
# 28982    85.0   BRONX
# 28983    80.0   BRONX
# 28984    80.0   BRONX
# 28985    80.0   BRONX
# 28986    85.0   BRONX
#
# [28987 rows x 16 columns]

# %%
#Save to CSV
#df3.to_csv("bronxheat.csv",index=False)
