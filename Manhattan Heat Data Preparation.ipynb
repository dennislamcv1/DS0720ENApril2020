# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# The goal of this exercise is to do Model Development and Validation to find the answer to the Question 4 of the problem statement:
#
# Can a predictive model be built for future prediction of the possibility of complaints of the specific type that you identified in response to Question 1?

# %% [markdown]
# Using the best model, you need to predict the number of future complaints (of the Complaint Type that you decided to focus on in Question 1).

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %matplotlib inline
sns.set_style('darkgrid')
sns.set(font_scale=1.5)


import feature_engine.missing_data_imputers as mdi
from feature_engine.outlier_removers import Winsorizer

import warnings
warnings.filterwarnings('ignore')


pd.options.display.max_columns= None
#pd.options.display.max_rows = None

# %% [markdown]
# ### Data Exploration

# %%
df = pd.read_csv("heat.csv")

# %%
df
# Out:
#           ComplaintType  Zipcode              Street    Borough
# 0        HEAT/HOT WATER  10019.0    WEST   52 STREET  MANHATTAN
# 1        HEAT/HOT WATER  11372.0           37 AVENUE     QUEENS
# 2        HEAT/HOT WATER  10458.0  SOUTHERN BOULEVARD      BRONX
# 3        HEAT/HOT WATER  10456.0       MORRIS AVENUE      BRONX
# 4        HEAT/HOT WATER  11372.0           81 STREET     QUEENS
# ...                 ...      ...                 ...        ...
# 1847750  HEAT/HOT WATER  10029.0    EAST  108 STREET  MANHATTAN
# 1847751  HEAT/HOT WATER  10029.0    EAST  108 STREET  MANHATTAN
# 1847752  HEAT/HOT WATER  10461.0  BRUCKNER BOULEVARD      BRONX
# 1847753  HEAT/HOT WATER  10034.0      SHERMAN AVENUE  MANHATTAN
# 1847754  HEAT/HOT WATER  10467.0  WEST GUN HILL ROAD      BRONX
#
# [1847755 rows x 4 columns]

# %%
df.drop(['ComplaintType', 'Zipcode'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Street', 'Borough'], dtype='object')

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ### Segment Heat/Hot Water Cases for Manhattan

# %%
df['Borough'].value_counts()
# Out:
# BRONX            600147
# BROOKLYN         569310
# MANHATTAN        418432
# QUEENS           241660
# STATEN ISLAND     18206
# Name: Borough, dtype: int64

# %%
man = df[df['Borough'] == 'MANHATTAN']

# %%
man
# Out:
#                                Street    Borough
# 0                    WEST   52 STREET  MANHATTAN
# 7        FREDERICK DOUGLASS BOULEVARD  MANHATTAN
# 9                    WEST   22 STREET  MANHATTAN
# 10                 CENTRAL PARK NORTH  MANHATTAN
# 11                   WEST  151 STREET  MANHATTAN
# ...                               ...        ...
# 1847741                      BROADWAY  MANHATTAN
# 1847743              WEST   45 STREET  MANHATTAN
# 1847750              EAST  108 STREET  MANHATTAN
# 1847751              EAST  108 STREET  MANHATTAN
# 1847753                SHERMAN AVENUE  MANHATTAN
#
# [418432 rows x 2 columns]

# %%
man.reset_index(drop=True, inplace=True)

# %%
man
# Out:
#                               Street    Borough
# 0                   WEST   52 STREET  MANHATTAN
# 1       FREDERICK DOUGLASS BOULEVARD  MANHATTAN
# 2                   WEST   22 STREET  MANHATTAN
# 3                 CENTRAL PARK NORTH  MANHATTAN
# 4                   WEST  151 STREET  MANHATTAN
# ...                              ...        ...
# 418427                      BROADWAY  MANHATTAN
# 418428              WEST   45 STREET  MANHATTAN
# 418429              EAST  108 STREET  MANHATTAN
# 418430              EAST  108 STREET  MANHATTAN
# 418431                SHERMAN AVENUE  MANHATTAN
#
# [418432 rows x 2 columns]

# %%
df2 = pd.read_csv("manhattanclasstrain.csv")

# %%
df2
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0      76036.25       77.0      0.35      6.0       1.0  16942.0    100.00
# 1      76036.25       77.0      1.00      6.0       1.0  16942.0    126.93
# 2      76036.25       77.0      0.22      6.0       1.0  16942.0    100.00
# 3       9401.00       77.0      3.60      6.0       6.5   2523.0    100.00
# 4       9401.00       77.0      3.60      6.0       6.5   2523.0    100.00
# ...         ...        ...       ...      ...       ...      ...       ...
# 42961  20535.00       50.0      4.11      6.0       6.5   5000.0    100.00
# 42962   9401.00       77.0      3.60      6.0       6.5   6450.0    126.93
# 42963   9401.00       15.0      3.60      6.0       6.5  16942.0    126.93
# 42964   9401.00       77.0      3.60      6.0       6.5  16942.0    126.93
# 42965   9401.00       77.0      3.60      6.0       6.5  16942.0    126.93
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea   Age  \
# 0           1.0        5.0      6072.0   7650.0      0.60      2320.0  88.0
# 1           1.0        5.0      6072.0   7650.0      0.60      2320.0  88.0
# 2           1.0        5.0      6072.0   7650.0      0.60      2320.0  88.0
# 3           1.0        5.0      6072.0   7650.0      4.00      2320.0  78.0
# 4           1.0        5.0      6072.0   7650.0      4.00      2320.0  78.0
# ...         ...        ...         ...      ...       ...         ...   ...
# 42961       1.0        5.0      6072.0  20535.0      3.44      2320.0  63.0
# 42962       1.0        5.0      6072.0   7650.0      3.44      2320.0  78.0
# 42963       1.0        1.0      6072.0   7650.0      4.00      2320.0  57.0
# 42964       1.0        5.0      6072.0   7650.0      3.44      2320.0  78.0
# 42965       1.0        1.0      6072.0   7650.0      4.00      2320.0  48.0
#
#        Period  ComplaintType
# 0       120.0              3
# 1       120.0              3
# 2       120.0              0
# 3       110.0              0
# 4       110.0              2
# ...       ...            ...
# 42961    94.0              1
# 42962   110.0              4
# 42963    89.0              0
# 42964   110.0              0
# 42965    80.0              0
#
# [42966 rows x 16 columns]

# %%
heat = df2[df2['ComplaintType'] == 0]

# %%
heat
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 2      76036.25       77.0      0.22      6.0       1.0  16942.0    100.00
# 3       9401.00       77.0      3.60      6.0       6.5   2523.0    100.00
# 6      76036.25      183.0      0.83      3.4      10.0  16942.0    126.93
# 7       7500.00       75.0      0.19      3.4      10.0  16942.0    126.93
# 16     76036.25       77.0     10.35      6.0      14.0  16942.0    126.93
# ...         ...        ...       ...      ...       ...      ...       ...
# 42957  37482.00      117.0      4.19      6.0       6.5   8950.0    126.93
# 42960  76036.25      138.0      7.81      6.0       6.5  10000.0    126.93
# 42963   9401.00       15.0      3.60      6.0       6.5  16942.0    126.93
# 42964   9401.00       77.0      3.60      6.0       6.5  16942.0    126.93
# 42965   9401.00       77.0      3.60      6.0       6.5  16942.0    126.93
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea    Age  \
# 2           1.0        5.0      6072.0   7650.0      0.60      2320.0   88.0
# 3           1.0        5.0      6072.0   7650.0      4.00      2320.0   78.0
# 6           1.0        5.0      6072.0   7650.0     10.00      2320.0  101.0
# 7           1.0        1.0      6072.0   7650.0     10.00      2320.0   88.0
# 16          1.0       12.0      6072.0   7650.0     10.00      2320.0   18.0
# ...         ...        ...         ...      ...       ...         ...    ...
# 42957       1.0        6.0      6072.0  31531.0      3.44      2320.0   59.0
# 42960       1.0       10.0      6072.0  31531.0      3.44      2320.0   22.0
# 42963       1.0        1.0      6072.0   7650.0      4.00      2320.0   57.0
# 42964       1.0        5.0      6072.0   7650.0      3.44      2320.0   78.0
# 42965       1.0        1.0      6072.0   7650.0      4.00      2320.0   48.0
#
#        Period  ComplaintType
# 2       120.0              0
# 3       110.0              0
# 6       120.0              0
# 7       120.0              0
# 16       50.0              0
# ...       ...            ...
# 42957    90.0              0
# 42960    54.0              0
# 42963    89.0              0
# 42964   110.0              0
# 42965    80.0              0
#
# [17046 rows x 16 columns]

# %%
heat.reset_index(drop=True, inplace=True)

# %%
heat
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0      76036.25       77.0      0.22      6.0       1.0  16942.0    100.00
# 1       9401.00       77.0      3.60      6.0       6.5   2523.0    100.00
# 2      76036.25      183.0      0.83      3.4      10.0  16942.0    126.93
# 3       7500.00       75.0      0.19      3.4      10.0  16942.0    126.93
# 4      76036.25       77.0     10.35      6.0      14.0  16942.0    126.93
# ...         ...        ...       ...      ...       ...      ...       ...
# 17041  37482.00      117.0      4.19      6.0       6.5   8950.0    126.93
# 17042  76036.25      138.0      7.81      6.0       6.5  10000.0    126.93
# 17043   9401.00       15.0      3.60      6.0       6.5  16942.0    126.93
# 17044   9401.00       77.0      3.60      6.0       6.5  16942.0    126.93
# 17045   9401.00       77.0      3.60      6.0       6.5  16942.0    126.93
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea    Age  \
# 0           1.0        5.0      6072.0   7650.0      0.60      2320.0   88.0
# 1           1.0        5.0      6072.0   7650.0      4.00      2320.0   78.0
# 2           1.0        5.0      6072.0   7650.0     10.00      2320.0  101.0
# 3           1.0        1.0      6072.0   7650.0     10.00      2320.0   88.0
# 4           1.0       12.0      6072.0   7650.0     10.00      2320.0   18.0
# ...         ...        ...         ...      ...       ...         ...    ...
# 17041       1.0        6.0      6072.0  31531.0      3.44      2320.0   59.0
# 17042       1.0       10.0      6072.0  31531.0      3.44      2320.0   22.0
# 17043       1.0        1.0      6072.0   7650.0      4.00      2320.0   57.0
# 17044       1.0        5.0      6072.0   7650.0      3.44      2320.0   78.0
# 17045       1.0        1.0      6072.0   7650.0      4.00      2320.0   48.0
#
#        Period  ComplaintType
# 0       120.0              0
# 1       110.0              0
# 2       120.0              0
# 3       120.0              0
# 4        50.0              0
# ...       ...            ...
# 17041    90.0              0
# 17042    54.0              0
# 17043    89.0              0
# 17044   110.0              0
# 17045    80.0              0
#
# [17046 rows x 16 columns]

# %%
heat.shape
# Out:
# (17046, 16)

# %%
manheat = man.sample(n=17046, random_state=0)

# %%
manheat
# Out:
#                       Street    Borough
# 36482   FT WASHINGTON AVENUE  MANHATTAN
# 261281              3 AVENUE  MANHATTAN
# 371821        MADISON AVENUE  MANHATTAN
# 215945    ST NICHOLAS AVENUE  MANHATTAN
# 151958              1 AVENUE  MANHATTAN
# ...                      ...        ...
# 416342              BROADWAY  MANHATTAN
# 40905     ST NICHOLAS AVENUE  MANHATTAN
# 285946      WEST   14 STREET  MANHATTAN
# 57908           LENOX AVENUE  MANHATTAN
# 232965      WEST  139 STREET  MANHATTAN
#
# [17046 rows x 2 columns]

# %%
manheat.reset_index(drop=True,inplace=True)

# %%
manheat
# Out:
#                      Street    Borough
# 0      FT WASHINGTON AVENUE  MANHATTAN
# 1                  3 AVENUE  MANHATTAN
# 2            MADISON AVENUE  MANHATTAN
# 3        ST NICHOLAS AVENUE  MANHATTAN
# 4                  1 AVENUE  MANHATTAN
# ...                     ...        ...
# 17041              BROADWAY  MANHATTAN
# 17042    ST NICHOLAS AVENUE  MANHATTAN
# 17043      WEST   14 STREET  MANHATTAN
# 17044          LENOX AVENUE  MANHATTAN
# 17045      WEST  139 STREET  MANHATTAN
#
# [17046 rows x 2 columns]

# %%
df3 = pd.concat([heat,manheat],axis=1)

# %%
df3
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0      76036.25       77.0      0.22      6.0       1.0  16942.0    100.00
# 1       9401.00       77.0      3.60      6.0       6.5   2523.0    100.00
# 2      76036.25      183.0      0.83      3.4      10.0  16942.0    126.93
# 3       7500.00       75.0      0.19      3.4      10.0  16942.0    126.93
# 4      76036.25       77.0     10.35      6.0      14.0  16942.0    126.93
# ...         ...        ...       ...      ...       ...      ...       ...
# 17041  37482.00      117.0      4.19      6.0       6.5   8950.0    126.93
# 17042  76036.25      138.0      7.81      6.0       6.5  10000.0    126.93
# 17043   9401.00       15.0      3.60      6.0       6.5  16942.0    126.93
# 17044   9401.00       77.0      3.60      6.0       6.5  16942.0    126.93
# 17045   9401.00       77.0      3.60      6.0       6.5  16942.0    126.93
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea    Age  \
# 0           1.0        5.0      6072.0   7650.0      0.60      2320.0   88.0
# 1           1.0        5.0      6072.0   7650.0      4.00      2320.0   78.0
# 2           1.0        5.0      6072.0   7650.0     10.00      2320.0  101.0
# 3           1.0        1.0      6072.0   7650.0     10.00      2320.0   88.0
# 4           1.0       12.0      6072.0   7650.0     10.00      2320.0   18.0
# ...         ...        ...         ...      ...       ...         ...    ...
# 17041       1.0        6.0      6072.0  31531.0      3.44      2320.0   59.0
# 17042       1.0       10.0      6072.0  31531.0      3.44      2320.0   22.0
# 17043       1.0        1.0      6072.0   7650.0      4.00      2320.0   57.0
# 17044       1.0        5.0      6072.0   7650.0      3.44      2320.0   78.0
# 17045       1.0        1.0      6072.0   7650.0      4.00      2320.0   48.0
#
#        Period  ComplaintType                Street    Borough
# 0       120.0              0  FT WASHINGTON AVENUE  MANHATTAN
# 1       110.0              0              3 AVENUE  MANHATTAN
# 2       120.0              0        MADISON AVENUE  MANHATTAN
# 3       120.0              0    ST NICHOLAS AVENUE  MANHATTAN
# 4        50.0              0              1 AVENUE  MANHATTAN
# ...       ...            ...                   ...        ...
# 17041    90.0              0              BROADWAY  MANHATTAN
# 17042    54.0              0    ST NICHOLAS AVENUE  MANHATTAN
# 17043    89.0              0      WEST   14 STREET  MANHATTAN
# 17044   110.0              0          LENOX AVENUE  MANHATTAN
# 17045    80.0              0      WEST  139 STREET  MANHATTAN
#
# [17046 rows x 18 columns]

# %%
df3.columns
# Out:
# Index(['BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'LotArea',
#        'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea',
#        'ResidFAR', 'RetailArea', 'Age', 'Period', 'ComplaintType', 'Street',
#        'Borough'],
#       dtype='object')

# %%
df3.drop(['ComplaintType', 'Street'],axis=1,inplace=True)

# %%
df3
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0      76036.25       77.0      0.22      6.0       1.0  16942.0    100.00
# 1       9401.00       77.0      3.60      6.0       6.5   2523.0    100.00
# 2      76036.25      183.0      0.83      3.4      10.0  16942.0    126.93
# 3       7500.00       75.0      0.19      3.4      10.0  16942.0    126.93
# 4      76036.25       77.0     10.35      6.0      14.0  16942.0    126.93
# ...         ...        ...       ...      ...       ...      ...       ...
# 17041  37482.00      117.0      4.19      6.0       6.5   8950.0    126.93
# 17042  76036.25      138.0      7.81      6.0       6.5  10000.0    126.93
# 17043   9401.00       15.0      3.60      6.0       6.5  16942.0    126.93
# 17044   9401.00       77.0      3.60      6.0       6.5  16942.0    126.93
# 17045   9401.00       77.0      3.60      6.0       6.5  16942.0    126.93
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea    Age  \
# 0           1.0        5.0      6072.0   7650.0      0.60      2320.0   88.0
# 1           1.0        5.0      6072.0   7650.0      4.00      2320.0   78.0
# 2           1.0        5.0      6072.0   7650.0     10.00      2320.0  101.0
# 3           1.0        1.0      6072.0   7650.0     10.00      2320.0   88.0
# 4           1.0       12.0      6072.0   7650.0     10.00      2320.0   18.0
# ...         ...        ...         ...      ...       ...         ...    ...
# 17041       1.0        6.0      6072.0  31531.0      3.44      2320.0   59.0
# 17042       1.0       10.0      6072.0  31531.0      3.44      2320.0   22.0
# 17043       1.0        1.0      6072.0   7650.0      4.00      2320.0   57.0
# 17044       1.0        5.0      6072.0   7650.0      3.44      2320.0   78.0
# 17045       1.0        1.0      6072.0   7650.0      4.00      2320.0   48.0
#
#        Period    Borough
# 0       120.0  MANHATTAN
# 1       110.0  MANHATTAN
# 2       120.0  MANHATTAN
# 3       120.0  MANHATTAN
# 4        50.0  MANHATTAN
# ...       ...        ...
# 17041    90.0  MANHATTAN
# 17042    54.0  MANHATTAN
# 17043    89.0  MANHATTAN
# 17044   110.0  MANHATTAN
# 17045    80.0  MANHATTAN
#
# [17046 rows x 16 columns]

# %%
df3.duplicated(keep='first').sum()
# Out:
# 485

# %%
df3.drop_duplicates(keep='first',ignore_index=True, inplace=True)

# %%
df3
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  LotArea  LotDepth  \
# 0      76036.25       77.0      0.22      6.0       1.0  16942.0    100.00
# 1       9401.00       77.0      3.60      6.0       6.5   2523.0    100.00
# 2      76036.25      183.0      0.83      3.4      10.0  16942.0    126.93
# 3       7500.00       75.0      0.19      3.4      10.0  16942.0    126.93
# 4      76036.25       77.0     10.35      6.0      14.0  16942.0    126.93
# ...         ...        ...       ...      ...       ...      ...       ...
# 16556   9401.00       77.0      3.60      6.0       6.5   5000.0    102.50
# 16557  37482.00      117.0      4.19      6.0       6.5   8950.0    126.93
# 16558  76036.25      138.0      7.81      6.0       6.5  10000.0    126.93
# 16559   9401.00       15.0      3.60      6.0       6.5  16942.0    126.93
# 16560   9401.00       77.0      3.60      6.0       6.5  16942.0    126.93
#
#        NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  RetailArea    Age  \
# 0           1.0        5.0      6072.0   7650.0      0.60      2320.0   88.0
# 1           1.0        5.0      6072.0   7650.0      4.00      2320.0   78.0
# 2           1.0        5.0      6072.0   7650.0     10.00      2320.0  101.0
# 3           1.0        1.0      6072.0   7650.0     10.00      2320.0   88.0
# 4           1.0       12.0      6072.0   7650.0     10.00      2320.0   18.0
# ...         ...        ...         ...      ...       ...         ...    ...
# 16556       1.0        5.0      6072.0   7650.0      3.44      2320.0   78.0
# 16557       1.0        6.0      6072.0  31531.0      3.44      2320.0   59.0
# 16558       1.0       10.0      6072.0  31531.0      3.44      2320.0   22.0
# 16559       1.0        1.0      6072.0   7650.0      4.00      2320.0   57.0
# 16560       1.0        1.0      6072.0   7650.0      4.00      2320.0   48.0
#
#        Period    Borough
# 0       120.0  MANHATTAN
# 1       110.0  MANHATTAN
# 2       120.0  MANHATTAN
# 3       120.0  MANHATTAN
# 4        50.0  MANHATTAN
# ...       ...        ...
# 16556   110.0  MANHATTAN
# 16557    90.0  MANHATTAN
# 16558    54.0  MANHATTAN
# 16559    89.0  MANHATTAN
# 16560    80.0  MANHATTAN
#
# [16561 rows x 16 columns]

# %%
#Save to CSV
#df3.to_csv("manhattanheat.csv",index=False)
